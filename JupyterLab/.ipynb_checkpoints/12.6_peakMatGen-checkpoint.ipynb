# %%
dmso_poso <- read.table(paste("/sharedFolder/Data/5_CutTagAce/MACS2_220607_JT10123_MN00260_trimmed_","DMSO","/macs2_peak_q0.1_peaks.csv",sep=""), header = TRUE, sep = ",")
taze_poso <- read.table(paste("/sharedFolder/Data/5_CutTagAce/MACS2_220607_JT10123_MN00260_trimmed_","Taze","/macs2_peak_q0.1_peaks.csv",sep=""), header = TRUE, sep = ",")
vale_poso <- read.table(paste("/sharedFolder/Data/5_CutTagAce/MACS2_220607_JT10123_MN00260_trimmed_","Vale","/macs2_peak_q0.1_peaks.csv",sep=""), header = TRUE, sep = ",")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dmso_poso <- read.table(paste("/sharedFolder/Data/5_CutTagAce/MACS2_220607_JT10123_MN00260_trimmed_","DMSO","/macs2_peak_q0.1_peaks.csv",sep=""), header = TRUE, sep = ",")
#       2 taze_poso <- read.table(paste("/sharedFolder/Data/5_CutTagAce/MACS2_220607_JT10123_MN00260_trimmed_","Taze","/macs2_peak_q0.1_peaks.csv",sep=""), header = TRUE, sep = ",")
#       3 vale_poso <- read.table(paste("/sharedFolder/Data/5_CutTagAce/MACS2_220607_JT10123_MN00260_trimmed_","Vale","/macs2_peak_q0.1_peaks.csv",sep=""), header = TRUE, sep = ",")
#
# NameError: name 'dmso_poso' is not defined

# %%
dmso_poso = read.table(paste("/sharedFolder/Data/5_CutTagAce/MACS2_220607_JT10123_MN00260_trimmed_","DMSO","/macs2_peak_q0.1_peaks.csv",sep=""), header = TRUE, sep = ",")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dmso_poso = read.table(paste("/sharedFolder/Data/5_CutTagAce/MACS2_220607_JT10123_MN00260_trimmed_","DMSO","/macs2_peak_q0.1_peaks.csv",sep=""), header = TRUE, sep = ",")
#
# NameError: name 'read' is not defined
