# %%
# centering with 'scale()'
center_scale <- function(x) {
    scale(x, scale = FALSE)
}
library("pheatmap")
results="/sharedFolder/Results/All_hotspot/Data_Analysis/WT"
previousResults="/sharedFolder/Results/Hotspot/"
library("ggVennDiagram");
library("ggplot2")

# %%
a=as.matrix(read.table(paste(results,"rpm_hgtgtsHeatmap.csv",sep="/"),header=TRUE,row.names=1,sep=","))
a=a+0.00000000000000000001
a=a[sort((a[,2]/a[,1]),index.return=TRUE,decreasing=TRUE)$ix,]
par(mar=c(5.1, 4.1, 4.1, 8.1), xpd=TRUE)
par(xpd=TRUE)
my_palette <- colorRampPalette(c("blue", "white", "red"))(n = 10)
pp=heatmap(a[,c(1,2)][nrow(a[,c(1,2)]):1,], scale="none",cexCol=0.7,Rowv=NA,Colv=NA,col=my_palette,labRow = FALSE)
legend("topright", inset=c(-0.338,-0.1), legend=c("min", "ave", "max"), 
     fill=colorRampPalette(c("blue", "white", "red"))(3))
print("WT Taze")
write.table(a[,c(1,2)],paste(results,"/Taze.csv",sep=""),col.names=NA,sep=",")
# Out:
# [1] "WT Taze"
# plot without title

# %%
a=as.matrix(read.table(paste(results,"rpm_hgtgtsHeatmap.csv",sep="/"),header=TRUE,row.names=1,sep=","))
a=a+0.00000000000000000001
a=a[sort((a[,3]/a[,1]),index.return=TRUE,decreasing=TRUE)$ix,]
par(mar=c(5.1, 4.1, 4.1, 8.1), xpd=TRUE)
par(xpd=TRUE)
my_palette <- colorRampPalette(c("blue", "white", "red"))(n = 10)
pp=heatmap(a[,c(1,3)][nrow(a[,c(1,3)]):1,], scale="none",cexCol=0.7,Rowv=NA,Colv=NA,col=my_palette,labRow = FALSE)
legend("topright", inset=c(-0.338,-0.1), legend=c("min", "ave", "max"), 
     fill=colorRampPalette(c("blue", "white", "red"))(3))
print("WT Vale")
write.table(a[,c(1,3)],paste(results,"Vale.csv",sep="/"),sep=",",col.names=NA)
# Out:
# [1] "WT Vale"
# plot without title

# %%
a=as.matrix(read.table(paste(results,"rpm_hgtgtsHeatmap.csv",sep="/"),header=TRUE,row.names=1,sep=","))
a=a+0.00000000000000000001
a=a[sort((a[,2]/a[,3]),index.return=TRUE,decreasing=TRUE)$ix,]
par(mar=c(5.1, 4.1, 4.1, 8.1), xpd=TRUE)
par(xpd=TRUE)
my_palette <- colorRampPalette(c("blue", "white", "red"))(n = 1000)
pp=heatmap(a[,c(2,3)][nrow(a[,c(2,3)]):1,], scale="none",cexCol=0.7,Rowv=NA,Colv=NA,col=my_palette,labRow = FALSE)
legend("topright", inset=c(-0.338,-0.1), legend=c("min", "ave", "max"), 
     fill=colorRampPalette(c("blue", "white", "red"))(3))
write.table(a[,c(2,3)],paste(results,"TazVale.csv",sep="/"),sep=",",col.names=NA)
# Out:
# plot without title

# %%
#Venn diagram plot. Check how many hotspot are in common
Database=read.table(paste(previousResults,"Database.csv",sep="/"),header=TRUE,sep=",")
Database=Database[-grep("Idelalisib",Database[,6]),]
types=c("WT")
conditions=c("DMSO","Taze","Vale")
for(j in types){
subBase=Database[grep(j,Database[,6]),]
x <- list()
count=1
for(i in conditions){
x[[count]]=subBase[grep(i,subBase[,6]),7]
count=count+1
}
names(x)=conditions
pdf(paste(results,"/",j,".pdf",sep=""))
  p= ggVennDiagram(x)
p=p+ 
  scale_fill_gradient(low = "blue", high = "red")
  
plot(p,main=j)
dev.off()
plot(p,main=j)

print(j)
print(x) 
system("echo yeah")
}
jjj=(unlist(x))
j2=x
# Out:
# [1] "WT"
# $DMSO
#  [1] 699 197 108 710 712 260 727 732 734 736 747 754 759 762 766 775 788 791 217
# [20] 594 799 802 819 225 826 628 833 835 842 843 852 853 858 862 868 871 872 876
# [39] 886 758 816 228 865
#
# $Taze
#  [1] 699 197 709 710 712 152 260 726 156 516 729 734 736 737 739 747 754 758 759
# [20] 762 773 780 788 790 791 592 594 799 802 816 819 225 830 228 833 835 836 418
# [39] 842 843 845 858 669 865 871 872 886 804 775 826
#
# $Vale
#  [1] 197 709 710 712 713 734 737 747 758 759 762 773 775 788 791 217 594 799 801
# [20] 802 804 816 819 225 826 830 228 833 835 842 843 845 862 865 871 886 699 754
# [39] 858 872
# plot without title

# %%
DMSOSpec=setdiff(setdiff(x$DMSO,x$Vale),x$Taze)
TazeSpec=setdiff(setdiff(x$Taze,x$DMSO),x$Vale)
ValeSpec=setdiff(setdiff(x$Vale,x$DMSO),x$Taze)
TazVale=setdiff(intersect(x$Taze,x$Vale),x$DMSO)
TazDMSO=setdiff(intersect(x$Taze,x$DMSO),x$Vale)
DMSOVale=setdiff(intersect(x$ Vale,x$DMSO),x$Taze)
common=intersect(intersect(x$ Vale,x$DMSO),x$Taze)
#inter=intersect(intersect(x$DMSO,x$Vale),x$Taze)

# %%
#Venn diagram plot. Check how many hotspot are in common
Database=read.table(paste(previousResults,"Database.csv",sep="/"),header=TRUE,sep=",")
Database=Database[-grep("Idelalisib",Database[,6]),]
types=c("WT")
conditions=c("DMSO","Taze")
for(j in types){
subBase=Database[grep(j,Database[,6]),]
x <- list()
count=1
for(i in conditions){
x[[count]]=subBase[grep(i,subBase[,6]),7]
count=count+1
}
names(x)=conditions
pdf(paste(results,"/",j,".pdf",sep=""))
  p= ggVennDiagram(x)
p=p+ 
  scale_fill_gradient(low = "blue", high = "red")
  
plot(p,main=j)
dev.off()
plot(p,main=j)

print(j)
print(x) 
system("echo yeah")
}
# Out:
# [1] "WT"
# $DMSO
#  [1] 699 197 108 710 712 260 727 732 734 736 747 754 759 762 766 775 788 791 217
# [20] 594 799 802 819 225 826 628 833 835 842 843 852 853 858 862 868 871 872 876
# [39] 886 758 816 228 865
#
# $Taze
#  [1] 699 197 709 710 712 152 260 726 156 516 729 734 736 737 739 747 754 758 759
# [20] 762 773 780 788 790 791 592 594 799 802 816 819 225 830 228 833 835 836 418
# [39] 842 843 845 858 669 865 871 872 886 804 775 826
# plot without title

# %%
#Venn diagram plot. Check how many hotspot are in common
Database=read.table(paste(previousResults,"Database.csv",sep="/"),header=TRUE,sep=",")
Database=Database[-grep("Idelalisib",Database[,6]),]
types=c("WT")
conditions=c("DMSO","Vale")
for(j in types){
subBase=Database[grep(j,Database[,6]),]
x <- list()
count=1
for(i in conditions){
x[[count]]=subBase[grep(i,subBase[,6]),7]
count=count+1
}
names(x)=conditions
pdf(paste(results,"/",j,".pdf",sep=""))
  p= ggVennDiagram(x)
p=p+ 
  scale_fill_gradient(low = "blue", high = "red")
  
plot(p,main=j)
dev.off()
plot(p,main=j)

print(j)
print(x) 
system("echo yeah")
}
# Out:
# [1] "WT"
# $DMSO
#  [1] 699 197 108 710 712 260 727 732 734 736 747 754 759 762 766 775 788 791 217
# [20] 594 799 802 819 225 826 628 833 835 842 843 852 853 858 862 868 871 872 876
# [39] 886 758 816 228 865
#
# $Vale
#  [1] 197 709 710 712 713 734 737 747 758 759 762 773 775 788 791 217 594 799 801
# [20] 802 804 816 819 225 826 830 228 833 835 842 843 845 862 865 871 886 699 754
# [39] 858 872
# plot without title

# %%
#Venn diagram plot. Check how many hotspot are in common
Database=read.table(paste(previousResults,"Database.csv",sep="/"),header=TRUE,sep=",")
Database=Database[-grep("Idelalisib",Database[,6]),]
types=c("WT")
conditions=c("Taze","Vale")
for(j in types){
subBase=Database[grep(j,Database[,6]),]
x <- list()
count=1
for(i in conditions){
x[[count]]=subBase[grep(i,subBase[,6]),7]
count=count+1
}
names(x)=conditions
pdf(paste(results,"/",j,".pdf",sep=""))
  p= ggVennDiagram(x)
p=p+ 
  scale_fill_gradient(low = "blue", high = "red")
  
plot(p,main=j)
dev.off()
plot(p,main=j)

print(j)
print(x) 
system("echo yeah")
}
# Out:
# [1] "WT"
# $Taze
#  [1] 699 197 709 710 712 152 260 726 156 516 729 734 736 737 739 747 754 758 759
# [20] 762 773 780 788 790 791 592 594 799 802 816 819 225 830 228 833 835 836 418
# [39] 842 843 845 858 669 865 871 872 886 804 775 826
#
# $Vale
#  [1] 197 709 710 712 713 734 737 747 758 759 762 773 775 788 791 217 594 799 801
# [20] 802 804 816 819 225 826 830 228 833 835 842 843 845 862 865 871 886 699 754
# [39] 858 872
# plot without title

# %%
x$Taze=c(1,2,3)
x$DMSO=c(1,2,3)
x$Vale=c(1,2,3)
#Venn diagram plot. Check how many hotspot are in common

pdf(paste(results,"/",j,".pdf",sep=""))
  p= ggVennDiagram(x)
p=p+ 
  scale_fill_gradient(low = "blue", high = "red")
  
plot(p,main=j)
dev.off()
plot(p,main=j)

print(j)
print(x) 
system("echo yeah")
# Out:
# png
#   2
# [1] "WT"
# $DMSO
# [1] 1 2 3
#
# $Taze
# [1] 1 2 3
#
# $Vale
# [1] 1 2 3
# plot without title

# %%
#Venn diagram plot. Check how many hotspot are in common
Database=read.table(paste(previousResults,"Database.csv",sep="/"),header=TRUE,sep=",")
Database=Database[-grep("Idelalisib",Database[,6]),]
types=c("Ligase4")
toRemove=c()
conditions=c("DMSO","Taze","Vale")
for(j in types){
subBase=Database[grep(j,Database[,6]),]
    
for(i in seq(1,nrow(subBase))){
if(length(which(subBase[i,7]==jjj))==0){
toRemove=append(toRemove,i)
}

}    
subBase=subBase[-toRemove,]
x <- list()
count=1
for(i in conditions){
x[[count]]=subBase[grep(i,subBase[,6]),7]
count=count+1
}
names(x)=conditions
pdf(paste(results,"/",j,".pdf",sep=""))

   p= ggVennDiagram(x)
p=p+ 
  scale_fill_gradient(low = "blue", high = "red")
  
plot(p,main=j)
dev.off()
plot(p,main=j)

    
print(j)
print(x) 
system("echo yeah")
}
# Out:
# [1] "Ligase4"
# $DMSO
#  [1] 699 699 709 710 712 713 726 727 729 732 734 736 737 739 747 754 758 759 762
# [20] 766 773 775 780 788 790 791 799 801 802 804 816 816 819 826 830 833 835 835
# [39] 836 842 842 843 845 852 853 858 862 865 868 871 872 876 886
#
# $Taze
#  [1] 699 709 710 712 713 260 726 727 516 729 732 734 736 737 737 739 739 747 754
# [20] 758 759 762 766 773 773 773 775 780 788 790 790 791 592 594 799 801 802 804
# [39] 816 816 819 826 628 830 833 835 418 842 843 845 852 853 862 669 865 868 871
# [58] 872 876
#
# $Vale
#  [1] 699 709 710 712 713 726 727 516 729 732 734 736 737 739 747 754 758 759 762
# [20] 766 773 775 780 788 790 791 592 594 799 801 802 804 816 819 826 628 830 833
# [39] 835 842 843 845 852 853 858 862 862 669 865 868 871 872 876
# plot without title

# %%
#Venn diagram plot. Check how many hotspot are in common
Database=read.table(paste(previousResults,"Database.csv",sep="/"),header=TRUE,sep=",")
Database=Database[-grep("Idelalisib",Database[,6]),]
types=c("Ligase4")
toRemove=c()
conditions=c("DMSO","Taze")
for(j in types){
subBase=Database[grep(j,Database[,6]),]
    
for(i in seq(1,nrow(subBase))){
if(length(which(subBase[i,7]==jjj))==0){
toRemove=append(toRemove,i)
}

}    
subBase=subBase[-toRemove,]
x <- list()
count=1
for(i in conditions){
x[[count]]=subBase[grep(i,subBase[,6]),7]
count=count+1
}
names(x)=conditions
pdf(paste(results,"/",j,".pdf",sep=""))

   p= ggVennDiagram(x)
p=p+ 
  scale_fill_gradient(low = "blue", high = "red")
  
plot(p,main=j)
dev.off()
plot(p,main=j)

    
print(j)
print(x) 
system("echo yeah")
}
# Out:
# [1] "Ligase4"
# $DMSO
#  [1] 699 699 709 710 712 713 726 727 729 732 734 736 737 739 747 754 758 759 762
# [20] 766 773 775 780 788 790 791 799 801 802 804 816 816 819 826 830 833 835 835
# [39] 836 842 842 843 845 852 853 858 862 865 868 871 872 876 886
#
# $Taze
#  [1] 699 709 710 712 713 260 726 727 516 729 732 734 736 737 737 739 739 747 754
# [20] 758 759 762 766 773 773 773 775 780 788 790 790 791 592 594 799 801 802 804
# [39] 816 816 819 826 628 830 833 835 418 842 843 845 852 853 862 669 865 868 871
# [58] 872 876
# plot without title

# %%
#Venn diagram plot. Check how many hotspot are in common
Database=read.table(paste(previousResults,"Database.csv",sep="/"),header=TRUE,sep=",")
Database=Database[-grep("Idelalisib",Database[,6]),]
types=c("Ligase4")
toRemove=c()
conditions=c("DMSO","Vale")
for(j in types){
subBase=Database[grep(j,Database[,6]),]
    
for(i in seq(1,nrow(subBase))){
if(length(which(subBase[i,7]==jjj))==0){
toRemove=append(toRemove,i)
}

}    
subBase=subBase[-toRemove,]
x <- list()
count=1
for(i in conditions){
x[[count]]=subBase[grep(i,subBase[,6]),7]
count=count+1
}
names(x)=conditions
pdf(paste(results,"/",j,".pdf",sep=""))

   p= ggVennDiagram(x)
p=p+ 
  scale_fill_gradient(low = "blue", high = "red")
  
plot(p,main=j)
dev.off()
plot(p,main=j)

    
print(j)
print(x) 
system("echo yeah")
}
# Out:
# [1] "Ligase4"
# $DMSO
#  [1] 699 699 709 710 712 713 726 727 729 732 734 736 737 739 747 754 758 759 762
# [20] 766 773 775 780 788 790 791 799 801 802 804 816 816 819 826 830 833 835 835
# [39] 836 842 842 843 845 852 853 858 862 865 868 871 872 876 886
#
# $Vale
#  [1] 699 709 710 712 713 726 727 516 729 732 734 736 737 739 747 754 758 759 762
# [20] 766 773 775 780 788 790 791 592 594 799 801 802 804 816 819 826 628 830 833
# [39] 835 842 843 845 852 853 858 862 862 669 865 868 871 872 876
# plot without title

# %%
#Venn diagram plot. Check how many hotspot are in common
Database=read.table(paste(previousResults,"Database.csv",sep="/"),header=TRUE,sep=",")
Database=Database[-grep("Idelalisib",Database[,6]),]
types=c("Ligase4")
toRemove=c()
conditions=c("Taze","Vale")
for(j in types){
subBase=Database[grep(j,Database[,6]),]
    
for(i in seq(1,nrow(subBase))){
if(length(which(subBase[i,7]==jjj))==0){
toRemove=append(toRemove,i)
}

}    
subBase=subBase[-toRemove,]
x <- list()
count=1
for(i in conditions){
x[[count]]=subBase[grep(i,subBase[,6]),7]
count=count+1
}
names(x)=conditions
pdf(paste(results,"/",j,".pdf",sep=""))

   p= ggVennDiagram(x)
p=p+ 
  scale_fill_gradient(low = "blue", high = "red")
  
plot(p,main=j)
dev.off()
plot(p,main=j)

    
print(j)
print(x) 
system("echo yeah")
}
# Out:
# [1] "Ligase4"
# $Taze
#  [1] 699 709 710 712 713 260 726 727 516 729 732 734 736 737 737 739 739 747 754
# [20] 758 759 762 766 773 773 773 775 780 788 790 790 791 592 594 799 801 802 804
# [39] 816 816 819 826 628 830 833 835 418 842 843 845 852 853 862 669 865 868 871
# [58] 872 876
#
# $Vale
#  [1] 699 709 710 712 713 726 727 516 729 732 734 736 737 739 747 754 758 759 762
# [20] 766 773 775 780 788 790 791 592 594 799 801 802 804 816 819 826 628 830 833
# [39] 835 842 843 845 852 853 858 862 862 669 865 868 871 872 876
# plot without title

# %%
DMSOSpec2=setdiff(setdiff(x$DMSO,x$Vale),x$Taze)
TazeSpec2=setdiff(setdiff(x$Taze,x$DMSO),x$Vale)
ValeSpec2=setdiff(setdiff(x$Vale,x$DMSO),x$Taze)
TazVale2=setdiff(intersect(x$Taze,x$Vale),x$DMSO)
TazDMSO2=setdiff(intersect(x$Taze,x$DMSO),x$Vale)
DMSOVale2=setdiff(intersect(x$ Vale,x$DMSO),x$Taze)
common2=intersect(intersect(x$ Vale,x$DMSO),x$Taze)

# %%
#WT ZONE, rpm plots. 
#a=as.matrix(read.table(paste(results,"rpm_hgtgtsHeatmap.csv",sep="/"),header=TRUE,row.names=1,sep=","))
#write.table(a[sapply(setdiff(x$DMSO,x$Taze),toString),c(1,2)],"/sharedFolder/DMSOTaze_L.csv",col.names=NA,sep=",",quote=TRUE)
#write.table(a[sapply(intersect(x$DMSO,x$Taze),toString),c(1,2)],"/sharedFolder/DMSOTaze_M.csv",col.names=NA,sep=",",quote=TRUE)
#write.table(a[sapply(setdiff(x$Taze,x$DMSO),toString),c(1,2)],"/sharedFolder/DMSOTaze_R.csv",col.names=NA,sep=",",quote=TRUE)

# %%
#WT Zone
results="/sharedFolder/Results/All_hotspot/Data_Analysis/WT"
dir.create(paste(results,"/rpmPlot/",sep=""))
a=as.matrix(read.table(paste(results,"rpm_hgtgtsHeatmap.csv",sep="/"),header=TRUE,row.names=1,sep=","))

temp=a[sapply(setdiff(x$DMSO,x$Taze),toString),c(1,2)]
if(length(temp)>2){
temp=temp[sort(temp[,1],index.return=TRUE,decreasing=TRUE)$ix,]
}

temp2=a[sapply(intersect(x$DMSO,x$Taze),toString),c(1,2)]
if(length(temp2)>2){
temp2=temp2[sort(temp2[,1],index.return=TRUE,decreasing=TRUE)$ix,]
}
temp3=a[sapply(setdiff(x$Taze,x$DMSO),toString),c(1,2)]
if(length(temp3)>2){
temp3=temp3[sort(temp3[,1],index.return=TRUE,decreasing=TRUE)$ix,]
}
print("DMSO TAZE")
write.table(rbind(temp,temp2,temp3),paste(results,"/rpmPlot/Lig_DMSOTaze.csv",sep=""),col.names=NA,sep=",",quote=TRUE)

#write.table(a[sapply(setdiff(x$DMSO,x$Taze),toString),c(1,2)],paste(results,"/rpmPlot/Lig_DMSOTaze_L.csv",sep=""),col.names=NA,sep=",",quote=TRUE)
#write.table(a[sapply(intersect(x$DMSO,x$Taze),toString),c(1,2)],paste(results,"/rpmPlot/Lig_DMSOTaze_M.csv",sep=""),col.names=NA,sep=",",quote=TRUE)
#write.table(a[sapply(setdiff(x$Taze,x$DMSO),toString),c(1,2)],paste(results,"/rpmPlot/Lig_DMSOTaze_R.csv",sep=""),col.names=NA,sep=",",quote=TRUE)

temp=a[sapply(setdiff(x$DMSO,x$Vale),toString),c(1,3)]
if(length(temp)>2){
temp=temp[sort(temp[,1],index.return=TRUE,decreasing=TRUE)$ix,]
}
temp2=a[sapply(intersect(x$DMSO,x$Vale),toString),c(1,3)]
if(length(temp2)>2){
temp2=temp2[sort(temp2[,1],index.return=TRUE,decreasing=TRUE)$ix,]
}
temp3=a[sapply(setdiff(x$Vale,x$DMSO),toString),c(1,3)]
if(length(temp3)>2){
temp3=temp3[sort(temp3[,1],index.return=TRUE,decreasing=TRUE)$ix,]
}
print("DMSO Vale")

write.table(rbind(temp,temp2,temp3),paste(results,"/rpmPlot/Lig_DMSOVale.csv",sep=""),col.names=NA,sep=",",quote=TRUE)

#write.table(a[sapply(setdiff(x$DMSO,x$Vale),toString),c(1,3)],"/sharedFolder/LIG_DMSOVale_L.csv",col.names=NA,sep=",",quote=TRUE)
#write.table(a[sapply(intersect(x$DMSO,x$Vale),toString),c(1,3)],paste(results,"/rpmPlot/LIG_DMSOVale_M.csv",sep=""),col.names=NA,sep=",",quote=TRUE)
#write.table(a[sapply(setdiff(x$Vale,x$DMSO),toString),c(1,3)],paste(results,"/rpmPlot/LIG_DMSOVale_R.csv",sep=""),col.names=NA,sep=",",quote=TRUE)

temp=a[sapply(setdiff(x$Taze,x$Vale),toString),c(2,3)]
if(length(temp)>2){
temp=temp[sort(temp[,1],index.return=TRUE,decreasing=TRUE)$ix,]
}
temp2=a[sapply(intersect(x$Taze,x$Vale),toString),c(2,3)]
if(length(temp2)>2){
temp2=temp2[sort(temp2[,1],index.return=TRUE,decreasing=TRUE)$ix,]
}
temp3=a[sapply(setdiff(x$Vale,x$Taze),toString),c(2,3)]
if(length(temp3)>2){
temp3=as.matrix(temp3[sort(temp3[,1],index.return=TRUE,decreasing=TRUE)$ix,])
}
print("Taze Vale")
write.table(rbind(temp,temp2,temp3),paste(results,"/rpmPlot/Lig_TazeValeee.csv",sep=""),col.names=NA,sep=",",quote=TRUE)

#write.table(a[sapply(setdiff(x$Taze,x$Vale),toString),c(2,3)],"/sharedFolder/LIG_TazVale_L.csv",col.names=NA,sep=",",quote=TRUE)
#write.table(a[sapply(intersect(x$Taze,x$Vale),toString),c(2,3)],paste(results,"/rpmPlot/LIG_TazVale_M.csv",sep=""),col.names=NA,sep=",",quote=TRUE)
#write.table(a[sapply(setdiff(x$Vale,x$Taze),toString),c(2,3)],paste(results,"/rpmPlot/LIG_TazVale_R.csv",sep=""),col.names=NA,sep=",",quote=TRUE)


#write.table(a[sapply(union(x$DMSO,x$Vale),toString),c(1,3)],"/sharedFolder/DMSOVale.csv",col.names=NA,sep=",",quote=TRUE)
#write.table(a[sapply(union(x$Vale,x$Taze),toString),c(2,3)],"/sharedFolder/TazeVale.csv",col.names=NA,sep=",",quote=TRUE)
#write.table(a[sapply(union(union(x$Vale,x$Taze),x$DMSO),toString),],"/sharedFolder/WT.csv",col.names=NA,sep=",",quote=TRUE)

#write.table(a[sapply(TazeSpec,toString),c(1,2)],"/sharedFolder/TazeSPEC.csv",col.names=NA,sep=",")
#write.table(a[sapply(ValeSpec,toString),],"/sharedFolder/ValeSPEC.csv",col.names=NA,sep=",")
#write.table(a[sapply(TazVale,toString),],"/sharedFolder/TazValeSPEC.csv",col.names=NA,sep=",")
#write.table(a[sapply(TazDMSO,toString),],"/sharedFolder/TazDMSOSPEC.csv",col.names=NA,sep=",")
#write.table(a[sapply(DMSOVale,toString),],"/sharedFolder/ValeDMSOSPEC.csv",col.names=NA,sep=",")
# Out:
# [1] "DMSO TAZE"
# [1] "DMSO Vale"
# [1] "Taze Vale"

# %%
#Ligase Zone
results="/sharedFolder/Results/All_hotspot/Data_Analysis/Lig4"
dir.create(paste(results,"/rpmPlot/",sep=""))
a=as.matrix(read.table(paste(results,"rpm_hgtgtsHeatmap.csv",sep="/"),header=TRUE,row.names=1,sep=","))

temp=a[sapply(setdiff(x$DMSO,x$Taze),toString),c(1,2)]
if(length(temp)>2){
temp=temp[sort(temp[,1],index.return=TRUE,decreasing=TRUE)$ix,]
}

temp2=a[sapply(intersect(x$DMSO,x$Taze),toString),c(1,2)]
if(length(temp2)>2){
temp2=temp2[sort(temp2[,1],index.return=TRUE,decreasing=TRUE)$ix,]
}
temp3=a[sapply(setdiff(x$Taze,x$DMSO),toString),c(1,2)]
if(length(temp3)>2){
temp3=temp3[sort(temp3[,1],index.return=TRUE,decreasing=TRUE)$ix,]
}
print("DMSO TAZE")

print(temp)
print("stop")
print(temp2)
print("stop")
print(temp3)
write.table(rbind(temp,temp2,temp3),paste(results,"/rpmPlot/Lig_DMSOTaze.csv",sep=""),col.names=NA,sep=",",quote=TRUE)

temp=a[sapply(setdiff(x$DMSO,x$Vale),toString),c(1,3)]
if(length(temp)>2){
temp=temp[sort(temp[,1],index.return=TRUE,decreasing=TRUE)$ix,]
}
temp2=a[sapply(intersect(x$DMSO,x$Vale),toString),c(1,3)]
if(length(temp2)>2){
temp2=temp2[sort(temp2[,1],index.return=TRUE,decreasing=TRUE)$ix,]
}
temp3=a[sapply(setdiff(x$Vale,x$DMSO),toString),c(1,3)]
if(length(temp3)>2){
temp3=temp3[sort(temp3[,1],index.return=TRUE,decreasing=TRUE)$ix,]
}

print("DMSO Vale")
print(temp)
print("stop")
print(temp2)
print("stop")
print(temp3)
write.table(rbind(temp,temp2,temp3),paste(results,"/rpmPlot/Lig_DMSOVale.csv",sep=""),col.names=NA,sep=",",quote=TRUE)

temp=a[sapply(setdiff(x$Taze,x$Vale),toString),c(2,3)]
if(length(temp)>2){
temp=temp[sort(temp[,1],index.return=TRUE,decreasing=TRUE)$ix,]
}
temp2=a[sapply(intersect(x$Taze,x$Vale),toString),c(2,3)]
if(length(temp2)>2){
temp2=temp2[sort(temp2[,1],index.return=TRUE,decreasing=TRUE)$ix,]
}
temp3=a[sapply(setdiff(x$Vale,x$Taze),toString),c(2,3)]
if(length(temp3)>2){
temp3=as.matrix(temp3[sort(temp3[,1],index.return=TRUE,decreasing=TRUE)$ix,])
}
print("Taze Vale")
print(temp)
print("stop")
print(temp2)
print("stop")
print(temp3)
write.table(rbind(temp,temp2,temp3),paste(results,"/rpmPlot/Lig_TazeValeee.csv",sep=""),col.names=NA,sep=",",quote=TRUE)
# Out:
# Warning message in dir.create(paste(results, "/rpmPlot/", sep = "")):
# “'/sharedFolder/Results/All_hotspot/Data_Analysis/Lig4/rpmPlot' already exists”
# [1] "DMSO TAZE"
#     Ligase4_KO_DMSO Ligase4_KO.Taze
# 886        5.781545        5.179695
# 858        5.646662        5.493640
# 836        5.144379        4.218960
# [1] "stop"
#     Ligase4_KO_DMSO Ligase4_KO.Taze
# 833       10.558697       11.031804
# 759       10.268359       10.515357
# 835       10.173412       10.402492
# 802       10.167265       10.364428
# 762       10.058550       10.315389
# 865       10.004409       10.340117
# 799        9.654988       10.201253
# 736        9.437279        9.072750
# 826        9.252209        9.197074
# 843        9.240547       10.320369
# 758        9.216935        9.472281
# 788        9.204982        8.814963
# 747        9.012686        9.350995
# 773        8.998907        9.498879
# 699        8.603141        8.428926
# 739        8.584810        8.586034
# ...

# %%
temp
# Out:
#     Ligase4_KO.Taze Ligase4_KO.Vale
# 418 5.969889        5.424391
# 260 4.992725        3.763758

# %%
library("eulerr")
VennDiag <- euler(c("Taze" = 12, "Vale" = 2, "DMSO" = 9,"DMSO&Taze"=2,"DMSO&Vale"=2,"Taze&Vale"=6,"DMSO&Taze&Vale"=30))
plot(VennDiag, counts = FALSE, font=2, cex=10, alpha=1,
     fill=c("gray", "lightgray", "white"),lab=FALSE)
# Out:
# plot without title

# %%
library("eulerr")
VennDiag <- euler(c("Taze" = 2,"Vale" = 1 ,"Taze&Vale"=51))
plot(VennDiag, counts = FALSE, font=1, cex=0, alpha=0.6,lab=FALSE,
     fill=c("lightgray","gray","black"))
# Out:
# plot without title

# %%
library(VennDiagram)
venn.plot <- draw.pairwise.venn(
area1 = 160,
area2 = 50,
cross.area =15,
#category = c("DMSO","Tazemetostat"),
#fill = c("#3399FF", "#FF8000"),
fill = c("black", "grey"),
col=c("black", "grey"),
alpha = c(0.5, 0.5),
rotation.degree = 0,
lty = "blank",
euler.d = TRUE,
cex = 2,
cat.col=c("black", "darkgray"),
cat.cex = 2,
cat.pos = c(285, 105),
cat.dist = 0.09,
cat.just = list(c(-1, -1), c(1, 1)),
ext.pos = 30,
ext.dist = -0.05,
ext.length = 0,
ext.line.lwd = 2,
ext.line.lty = "dashed",
offset=1
);
grid.draw(venn.plot);
# Out:
# plot without title

# %%
scale_colour_grey(
  start = 0.2,
  end = 0.8,
  na.value = "red",
  aesthetics = "colour"
)
# Out:
# <ggproto object: Class ScaleDiscrete, Scale, gg>
#     aesthetics: colour
#     axis_order: function
#     break_info: function
#     break_positions: function
#     breaks: waiver
#     call: call
#     clone: function
#     dimension: function
#     drop: TRUE
#     expand: waiver
#     get_breaks: function
#     get_breaks_minor: function
#     get_labels: function
#     get_limits: function
#     guide: legend
#     is_discrete: function
#     is_empty: function
#     labels: waiver
#     limits: NULL
#     make_sec_title: function
#     make_title: function
#     map: function
#     map_df: function
#     n.breaks.cache: NULL
#     na.translate: TRUE
#     na.value: red
#     name: waiver
#     palette: function
#     palette.cache: NULL
#     position: left
#     range: <ggproto object: Class RangeDiscrete, Range, gg>
#         range: NULL
#         reset: function
#         train: function
#         super:  <ggproto object: Class RangeDiscrete, Range, gg>
# ...

# %%
#Plot hotspot statistic Normalized and not 
bb=barplot(table(Database[,6]),main="Not normalized",cex.names=0.5,las=2)
text(bb,5,table(Database[,6]),cex=.8)
normalized=(table(Database[,6])/as.numeric(scoreDD[names(table(Database[,6])),2])*100)
bb=barplot(normalized,main="Normalized",cex.names=0.5,las=2)
pdf(paste(results,"/HotspotNumber.pdf",sep=""))
bb=barplot(table(Database[,6]),main="Not normalized",cex.names=0.5,las=2)
text(bb,5,table(Database[,6]),cex=.8)
normalized=(table(Database[,6])/as.numeric(scoreDD[names(table(Database[,6])),2])*100)
bb=barplot(normalized,main="Normalized",cex.names=0.5,las=2)
dev.off()
# Out:
# Error in eval(expr, envir, enclos): object 'scoreDD' not found
# Traceback:
# Plot with title “Not normalized”

# %%
types=c("AID_KO","Ligase4","WT","Idelalisib")
AIDH=Database[grep(types[1],Database[,6]),7]
AIDINDependent=c()
j=types[3]
subBase=Database[grep(j,Database[,6]),]
h1=list()
h2=list()
count=1
names1=c()
names2=c()
for(i in conditions){

subBase2=subBase[grep(i,subBase[,6]),]
h1[[count]]=length(c(intersect(subBase2[,7],AIDH)))
names1=append(names1,paste(i,"AID_indep"))
h2[[count]]=length(c(setdiff(subBase2[,7],AIDH)))   
names2=append(names2,paste(i,"AID_dep"))
count=count+1
AIDINDependent=append(AIDINDependent,intersect(subBase2[,7],AIDH))
}


bb=barplot(as.numeric(h2), width = 0.5,  col='red',main=j,las=2,names=names2,cex.names=0.5)
bb2=barplot(as.numeric(h1), width = 0.5, col='blue', add=T,main=j,las=2,cex.names=0.5)
text(bb,20,as.numeric(h2))
text(bb2,2,as.numeric(h1))
pdf(paste(results,"/",j,"HOTSPOT.pdf",sep=""))
bb=barplot(as.numeric(h2), width = 0.5,  col='red',main=j,las=2,names=names2,cex.names=0.5)
bb2=barplot(as.numeric(h1), width = 0.5, col='blue', add=T,main=j,las=2,cex.names=0.5)
text(bb,90,as.numeric(h2))
text(bb2,4,as.numeric(h1))    
dev.off()

aidIND=matrix(ncol=ncol(Database))
colnames(aidIND)=colnames(Database)
for(i in AIDINDependent){
aidIND=rbind(aidIND,Database[which(Database[,7]==i)[1],])
}
aidIND=aidIND[-1,-c(4,5,6)]
write.table(unique(aidIND),paste(results,"/HOTSPOT_AIDINDEPENDENT.csv",sep=""),sep=",",row.names=FALSE)
# Out:
# png
#   2
# Plot with title “WT”

# %%
bigbig=list()
AID_Indep=intersect(Database[grep("AID_KO",Database[,6]),7],Database[grep("AID_WT",Database[,6]),7])
AID_dep=setdiff(Database[grep("AID_WT",Database[,6]),7],Database[grep("AID_KO",Database[,6]),7])
#AID Indept
bigOne=read.table(paste(results,"/rpm_hgtgtsHeatmap.csv",sep=""),header=TRUE,sep=",",row.names=1)
bigOne=bigOne+0.0000000000001
AID_1=bigOne[sapply(AID_Indep,toString),]
bigbig$AID_Indep=cbind((AID_1[,2]/AID_1[,1]),(AID_1[,3]/AID_1[,1]))
#AID DEP
bigOne=read.table(paste(results,"/rpm_hgtgtsHeatmap.csv",sep=""),header=TRUE,sep=",",row.names=1)
bigOne=bigOne[sapply(inter,toString),]
bigOne=bigOne+0.0000000000001
AID_2=bigOne[sapply(AID_dep,toString),]
bigbig$AID_Dep=cbind((AID_2[,2]/AID_2[,1]),(AID_2[,3]/AID_2[,1]))
boxplot(bigbig)
# Out:
# plot without title

# %%
#SETTING PATH 
path="/sharedFolder/Data/HTGTS/4_Junction_Jianli_final/junction_pooled/"
pathGroseq="/sharedFolder/Data/gro-seq/"
previousResults="/sharedFolder/Results/Hotspot/"
results="/sharedFolder/Results/All_hotspot/Data_Analysis"
dir.create(results,recursive=TRUE)
riderPath="/home/Riderv2/"
a=list.files(path,pattern=".bed",recursive=TRUE)
a=mixedsort(a)
a2=sapply(a,FUN=function(x){strsplit(x,".bed")[[1]][1]})
a2=sapply(a2,FUN=function(x){strsplit(x,"__")[[1]][2]})
print("WT ANALYSIS")
results="/sharedFolder/Results/All_hotspot/Data_Analysis/WT"
dir.create(results,recursive=TRUE)
a2=a2[-grep("Idelalisib",a2)]
a2=a2[grep("WT",a2)]
a=a[-grep("Idelalisib",a)]
a=a[grep("WT",a)]
Database2=read.table("/sharedFolder/Database2.csv",header=TRUE,sep=",")
#Heatmap matrix generation for HTGTS data
hgtgts_count=matrix(0,ncol=length(unique(Database2[,7])),nrow=length(a2))
colnames(hgtgts_count)=sapply(unique(Database2[,7]),FUN=toString)
rownames(hgtgts_count)=a2
hgtgts_rpm=hgtgts_count
hgtgts_fpkm=hgtgts_count
for(j in a){
    system(paste("echo",j))
temp=read.table(paste(path,"/",j,sep=""),sep="\t")
tempGG=GRanges(seqnames=as.matrix(temp[,1]),ranges=IRanges(start = as.numeric(temp[,2]),end=as.numeric(temp[,3])))    
    for(i in seq(nrow(Database2))){
        system(paste("echo",i/nrow(Database2)))
        gg=GRanges(seqnames=as.matrix(Database2[i,1]),ranges=IRanges(start = as.numeric(Database2[i,2]),end=as.numeric(Database2[i,3])))    
        over=countOverlaps(gg,tempGG)
        name=as.vector(noExt(fNumber(j)))
        hgtgts_count[name,toString(Database2[i,7])]= over
        hgtgts_rpm[name,toString(Database2[i,7])]= ((over)/nrow(temp))*1000000
        hgtgts_fpkm[name,toString(Database2[i,7])]= ((((over)/nrow(temp))*1000000)/(Database2[i,3]-Database2[i,2]))*1000000
   }

}
#write.table(log2(t(hgtgts_count)+1),paste(results,"/","count_hgtgtsHeatmap.csv",sep=""),col.names=NA,sep=",")
#write.table(log2(t(hgtgts_rpm)+1),paste(results,"/","rpm_hgtgtsHeatmap.csv",sep=""),col.names=NA,sep=",")
#write.table(log2(t(hgtgts_fpkm)+1),paste(results,"/","fpkm_hgtgtsHeatmap.csv",sep=""),col.names=NA,sep=",")
write.table((t(hgtgts_count)),paste(results,"/","countRAW_hgtgtsHeatmap_AIDonTarget.csv",sep=""),col.names=NA,sep=",")
bigbig$AID_OnTarget=cbind((hgtgts_count[2,]/hgtgts_count[1,]),(hgtgts_count[3,]/hgtgts_count[1,]))
# Out:
# Warning message in dir.create(results, recursive = TRUE):
# “'/sharedFolder/Results/All_hotspot/Data_Analysis' already exists”
# [1] "WT ANALYSIS"
# Warning message in dir.create(results, recursive = TRUE):
# “'/sharedFolder/Results/All_hotspot/Data_Analysis/WT' already exists”

# %%
   
  # take the x-axis indices and add a jitter, proportional to the N in each level
# Out:
# plot without title

# %%
bigbig

# %%
group <- sample(LETTERS[1:3], size = 200,
                replace = TRUE)

# %%
bigbig

# %%
bigbig

# %%
length(x$Taze)
# Out:
# [1] 50
