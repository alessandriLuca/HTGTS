# %%
noExt=function(x){
return(tools::file_path_sans_ext(x))
}
bnoExt=function(x){
return(basename(tools::file_path_sans_ext(x)))
}
fNumber=function(x){
sapply(x,FUN=function(x){
strsplit(x,"__")[[1]][2]
})
}
rRider=function(x){
sapply(x,FUN=function(x){
strsplit(x,"-RIDER")[[1]][1]
})
}
# centering with 'scale()'
center_scale <- function(x) {
    scale(x, scale = FALSE)
}
#LOAD LIBRARIES 
library(gtools);
library("GenomicRanges");
options(warn=-1)
library(ggplot2)

# %%
#SETTING PATH 
pathGroseq="/sharedFolder/Data/3_gro_seq/bed/"
results="/sharedFolder/Results/Sequencing"
previousResults="/sharedFolder/Results/Hotspot/"
dir.create(results,recursive=TRUE)
results="/sharedFolder/Results/Sequencing/groSeq"
dir.create(results,recursive=TRUE)

# %%
dir.create(results,recursive=TRUE)
Database=read.table(paste(previousResults,"Database.csv",sep="/"),header=TRUE,sep=",")

# %%
gtf=read.table(paste(previousResults,"Database.csv",sep="/"),header=TRUE,sep=",")
gtf=gtf[grep("Ligase",gtf[,6]),]
a=list.files(pathGroseq,pattern=".bed",recursive=TRUE)
uu=grep("sorted",a)
if(length(uu)!=0){
a=a[-uu]
    }
a=mixedsort(a)
a2=sapply(a,FUN=function(x){strsplit(x,".bed")[[1]][1]})
groseq_count=matrix(0,ncol=length(unique(gtf[,7])),nrow=length(a2))
colnames(groseq_count)=sapply(unique(gtf[,7]),FUN=toString)
rownames(groseq_count)=a2
groseq_rpm=groseq_count
for(j in a){
    system(paste("echo",j))
temp=read.table(paste(pathGroseq,"/",j,sep=""),sep="\t")
tempGG=GRanges(seqnames=as.matrix(temp[,1]),ranges=IRanges(start = as.numeric(temp[,2]),end=as.numeric(temp[,3])),mcols=abs(as.numeric(temp[,4])))
    for(i in seq(nrow(gtf))){
        system(paste("echo",i/nrow(gtf)))
        gg=GRanges(seqnames=as.matrix(gtf[i,1]),ranges=IRanges(start = as.numeric(gtf[i,2]),end=as.numeric(gtf[i,3])))    
        over=findOverlaps(gg,tempGG)@to    
        name=as.vector(noExt((j)))
        groseq_count[name,toString(gtf[i,7])]= sum(tempGG[over]$mcols)
        groseq_rpm[name,toString(gtf[i,7])]= (sum(tempGG[over]$mcols)/sum(abs(temp[,4])))*1000000

   }

}

# %%
conditions=c("DMSO","Taze","Vale")
groseq_newcount=matrix(ncol=ncol(groseq_count))
groseq_newrpm=groseq_newcount
 for(i in conditions){
summa=t(as.matrix(colSums(groseq_count[grep(i,rownames(groseq_count)),])))
groseq_newcount=rbind(groseq_newcount,summa)
summa=t(as.matrix(colSums(groseq_rpm[grep(i,rownames(groseq_rpm)),])))
groseq_newrpm=rbind(groseq_newrpm,summa)

}
groseq_newrpm=groseq_newrpm[-1,]
groseq_newcount=groseq_newcount[-1,]
rownames(groseq_newrpm)=conditions
rownames(groseq_newcount)=conditions

write.table((t(groseq_newcount)),paste(results,"/groSeq_AID_Heatmap_count.csv",sep=""),col.names=NA,sep=",")
write.table((t(groseq_newrpm)),paste(results,"/groSeq_AID_Heatmap_RPM.csv",sep=""),col.names=NA,sep=",")

# %%
print("RAW")
Database=read.table(paste(previousResults,"Database.csv",sep="/"),header=TRUE,sep=",")
groseq_newrpm=as.matrix(read.table(paste(results,"/groSeq_AID_Heatmap_RPM.csv",sep=""),header=TRUE,row.names=1,sep=","))

ttmp=groseq_newrpm[which(groseq_newrpm[,1]>=summary(groseq_newrpm[,1])[5]),]
thresholdTheBest=unique(union(names(sort(ttmp[,2]/ttmp[,1],decreasing=TRUE))[seq(1,20)],names(sort(ttmp[,3]/ttmp[,1],decreasing=TRUE))[seq(1,20)]))

foldChange=list()
geneWide=groseq_newrpm+0.000001
filteringTazeBS=names(sort(geneWide[,2],decreasing=TRUE))[seq(1,75)]
filteringValeBS=names(sort(geneWide[,3],decreasing=TRUE))[seq(1,75)]
filteringBS=union(filteringTazeBS,filteringValeBS)


#geneWide=geneWide[filtering,]
foldChange[[1]]=log2(geneWide[,2]/geneWide[,1])
foldChange[[2]]=log2(geneWide[,3]/geneWide[,1])


filteringTazeLFC=names(sort(foldChange[[1]],decreasing=TRUE))[seq(1,75)]
filteringValeLFC=names(sort(foldChange[[2]],decreasing=TRUE))[seq(1,75)]
filteringLFC=union(filteringTazeLFC,filteringValeLFC)

filtering=intersect(filteringBS,filteringLFC)

names(foldChange)=c("Taze","Vale")

foldChangeDF=cbind(foldChange[[1]],rep("Taze",length(foldChange[[1]])))
foldChangeDF=rbind(foldChangeDF,cbind(foldChange[[2]],rep("Vale",length(foldChange[[2]]))))
foldChangeDF=rbind(foldChangeDF,cbind(0,rep("DMSO",length(foldChange[[1]]))))
lim=max(abs(foldChange[[1]]),abs(foldChange[[2]]))

colnames(foldChangeDF)=c("lfc","drug")
foldChangeDF=data.frame(foldChangeDF,check.names=FALSE,fix.empty.names=FALSE)
foldChangeDF$lfc=as.numeric(foldChangeDF$lfc)

pp=ggplot(foldChangeDF,aes(x=drug,y=lfc,fill="red")) +
geom_violin(alpha = 0.5) +
geom_point(position = position_jitter(seed = 1, width = 0.2),size=0.1) +
theme(legend.position = "none") + ylim(-3,3) + ggtitle("Groseq LogFoldChange AID Dependent")
plot(pp)   
print("Strongest")
tempforever=c()
for(i in filtering){
temp=unique(Database[which(Database[,7]==i),c(1,2,3)])
tempforever=append(tempforever,(paste(temp[,1],":",temp[,2],"-",temp[,3],sep="")))
}
write.table(tempforever,(paste(results,"/gro_seq_raw_strongest.csv",sep="")),sep=",",col.names=FALSE,row.names=FALSE,quote=FALSE)
print("Most DE")
tempforever=c()

for(i in filteringLFC[seq(1,10)]){
temp=unique(Database[which(Database[,7]==i),c(1,2,3)])
tempforever=append(tempforever,(paste(temp[,1],":",temp[,2],"-",temp[,3],sep="")))

}
write.table(tempforever,(paste(results,"/gro_seq_raw_mostDE.csv",sep="")),sep=",",col.names=FALSE,row.names=FALSE,quote=FALSE)
tempforever=c()

print("Most DE with Threshold")
for(i in thresholdTheBest){
temp=unique(Database[which(Database[,7]==i),c(1,2,3)])
tempforever=append(tempforever,(paste(temp[,1],":",temp[,2],"-",temp[,3],sep="")))
}
write.table(tempforever,(paste(results,"/gro_seq_raw_mostDETreshold.csv",sep="")),sep=",",col.names=FALSE,row.names=FALSE,quote=FALSE)
# Out:
# [1] "RAW"
# [1] "Strongest"
# [1] "Most DE"
# [1] "Most DE with Threshold"
# plot without title

# %%
print("pvalue Filtered")
Database=read.table(paste(previousResults,"Database.csv",sep="/"),header=TRUE,sep=",")
groseq_newrpm=as.matrix(read.table(paste(results,"/groSeq_AID_Heatmap_RPM.csv",sep=""),header=TRUE,row.names=1,sep=","))
filter=unique(union(rownames(read.table("/sharedFolder/Results/Ligase4/rpmPlot/filtered/filtered_Lig_DMSOVale.csv",header=TRUE,row.names=1,sep=",")),rownames(read.table("/sharedFolder/Results/Ligase4/rpmPlot/filtered/filtered_Lig_DMSOTaze.csv",header=TRUE,row.names=1,sep=","))))
filter=unlist(sapply(filter,FUN=function(x){toString(x)}))
groseq_newrpm=groseq_newrpm[filter,]
write.table(groseq_newrpm,paste(results,"/groSeq_AID_Heatmap_RPM_FILTERED.csv",sep=""),col.names=NA,sep=",")
ttmp=groseq_newrpm[which(groseq_newrpm[,1]>=summary(groseq_newrpm[,1])[5]),]
thresholdTheBest=unique(union(names(sort(ttmp[,2]/ttmp[,1],decreasing=TRUE))[seq(1,20)],names(sort(ttmp[,3]/ttmp[,1],decreasing=TRUE))[seq(1,20)]))

foldChange=list()
geneWide=groseq_newrpm+0.000001
filteringTazeBS=names(sort(geneWide[,2],decreasing=TRUE))[seq(1,75)]
filteringValeBS=names(sort(geneWide[,3],decreasing=TRUE))[seq(1,75)]
filteringBS=union(filteringTazeBS,filteringValeBS)


#geneWide=geneWide[filtering,]
foldChange[[1]]=log2(geneWide[,2]/geneWide[,1])
foldChange[[2]]=log2(geneWide[,3]/geneWide[,1])


filteringTazeLFC=names(sort(foldChange[[1]],decreasing=TRUE))[seq(1,75)]
filteringValeLFC=names(sort(foldChange[[2]],decreasing=TRUE))[seq(1,75)]
filteringLFC=union(filteringTazeLFC,filteringValeLFC)

filtering=intersect(filteringBS,filteringLFC)

names(foldChange)=c("Taze","Vale")

foldChangeDF=cbind(foldChange[[1]],rep("Taze",length(foldChange[[1]])))
foldChangeDF=rbind(foldChangeDF,cbind(foldChange[[2]],rep("Vale",length(foldChange[[2]]))))
foldChangeDF=rbind(foldChangeDF,cbind(0,rep("DMSO",length(foldChange[[1]]))))
lim=max(abs(foldChange[[1]]),abs(foldChange[[2]]))

colnames(foldChangeDF)=c("lfc","drug")
foldChangeDF=data.frame(foldChangeDF,check.names=FALSE,fix.empty.names=FALSE)
foldChangeDF$lfc=as.numeric(foldChangeDF$lfc)

pp=ggplot(foldChangeDF,aes(x=drug,y=lfc,fill="red")) +
geom_violin(alpha = 0.5) +
geom_point(position = position_jitter(seed = 1, width = 0.2),size=0.1) +
theme(legend.position = "none") + ylim(-3,3) + ggtitle("Groseq LogFoldChange AID Dependent")
plot(pp)   
print("Strongest")
tempforever=c()
for(i in filtering){
temp=unique(Database[which(Database[,7]==i),c(1,2,3)])
tempforever=append(tempforever,(paste(temp[,1],":",temp[,2],"-",temp[,3],sep="")))
}
write.table(tempforever,(paste(results,"/gro_seq_filtered_strongest.csv",sep="")),sep=",",col.names=FALSE,row.names=FALSE,quote=FALSE)
print("Most DE")
tempforever=c()

for(i in filteringLFC[seq(1,10)]){
temp=unique(Database[which(Database[,7]==i),c(1,2,3)])
tempforever=append(tempforever,(paste(temp[,1],":",temp[,2],"-",temp[,3],sep="")))

}
write.table(tempforever,(paste(results,"/gro_seq_filtered_mostDE.csv",sep="")),sep=",",col.names=FALSE,row.names=FALSE,quote=FALSE)
tempforever=c()

print("Most DE with Threshold")
for(i in thresholdTheBest){
temp=unique(Database[which(Database[,7]==i),c(1,2,3)])
tempforever=append(tempforever,(paste(temp[,1],":",temp[,2],"-",temp[,3],sep="")))
}
write.table(tempforever,(paste(results,"/gro_seq_filtered_mostDETreshold.csv",sep="")),sep=",",col.names=FALSE,row.names=FALSE,quote=FALSE)
# Out:
# [1] "pvalue Filtered"
# [1] "Strongest"
# [1] "Most DE"
# [1] "Most DE with Threshold"
# plot without title

# %%
gtf=read.table("/sharedFolder/Data/refGene.gtf",header=TRUE,sep="\t")
a=list.files(pathGroseq,pattern=".bed",recursive=TRUE)
uu=grep("sorted",a)
if(length(uu)!=0){
a=a[-uu]
    }
a=mixedsort(a)
a2=sapply(a,FUN=function(x){strsplit(x,".bed")[[1]][1]})
groseq_count=matrix(0,ncol=length(unique(gtf[,4])),nrow=length(a2))
colnames(groseq_count)=sapply(unique(gtf[,4]),FUN=toString)
rownames(groseq_count)=a2
groseq_rpm=groseq_count
for(j in a){
    system(paste("echo",j))
temp=read.table(paste(pathGroseq,"/",j,sep=""),sep="\t")
tempGG=GRanges(seqnames=as.matrix(temp[,1]),ranges=IRanges(start = as.numeric(temp[,2]),end=as.numeric(temp[,3])),mcols=abs(as.numeric(temp[,4])))
    for(i in seq(nrow(gtf))){
        system(paste("echo",i/nrow(gtf)))
        gg=GRanges(seqnames=as.matrix(gtf[i,1]),ranges=IRanges(start = as.numeric(gtf[i,2]),end=as.numeric(gtf[i,3])))    
        over=findOverlaps(gg,tempGG)@to    
        name=as.vector(noExt((j)))
        groseq_count[name,toString(gtf[i,4])]= sum(tempGG[over]$mcols)
        groseq_rpm[name,toString(gtf[i,4])]= (sum(tempGG[over]$mcols)/sum(abs(temp[,4])))*1000000

   }

}
conditions=c("DMSO","Taze","Vale")
groseq_newcount=matrix(ncol=ncol(groseq_count))
groseq_newrpm=groseq_newcount
 for(i in conditions){
summa=t(as.matrix(colSums(groseq_count[grep(i,rownames(groseq_count)),])))
groseq_newcount=rbind(groseq_newcount,summa)
summa=t(as.matrix(colSums(groseq_rpm[grep(i,rownames(groseq_rpm)),])))
groseq_newrpm=rbind(groseq_newrpm,summa)

}
groseq_newrpm=groseq_newrpm[-1,]
groseq_newcount=groseq_newcount[-1,]
rownames(groseq_newrpm)=conditions
rownames(groseq_newcount)=conditions

write.table((t(groseq_newcount)),paste(results,"/groSeq_geneWide_count.csv",sep=""),col.names=NA,sep=",")
write.table((t(groseq_newrpm)),paste(results,"/groSeq_geneWide_RPM.csv",sep=""),col.names=NA,sep=",")

# %%
print("Gene wide ")

groseq_newrpm=as.matrix(read.table(paste(results,"/groSeq_geneWide_RPM.csv",sep=""),header=TRUE,row.names=1,sep=","))
ttmp=groseq_newrpm[which(groseq_newrpm[,1]>=summary(groseq_newrpm[,1])[5]),]
thresholdTheBest=unique(union(names(sort(ttmp[,2]/ttmp[,1],decreasing=TRUE))[seq(1,20)],names(sort(ttmp[,3]/ttmp[,1],decreasing=TRUE))[seq(1,20)]))

foldChange=list()
geneWide=groseq_newrpm+0.000001
filteringTazeBS=names(sort(geneWide[,2],decreasing=TRUE))[seq(1,2000)]
filteringValeBS=names(sort(geneWide[,3],decreasing=TRUE))[seq(1,2000)]
filteringBS=union(filteringTazeBS,filteringValeBS)


#geneWide=geneWide[filtering,]
foldChange[[1]]=log2(geneWide[,2]/geneWide[,1])
foldChange[[2]]=log2(geneWide[,3]/geneWide[,1])


filteringTazeLFC=names(sort(foldChange[[1]],decreasing=TRUE))[seq(1,2000)]
filteringValeLFC=names(sort(foldChange[[2]],decreasing=TRUE))[seq(1,2000)]
filteringLFC=union(filteringTazeLFC,filteringValeLFC)

filtering=intersect(filteringBS,filteringLFC)

names(foldChange)=c("Taze","Vale")

foldChangeDF=cbind(foldChange[[1]],rep("Taze",length(foldChange[[1]])))
foldChangeDF=rbind(foldChangeDF,cbind(foldChange[[2]],rep("Vale",length(foldChange[[2]]))))
foldChangeDF=rbind(foldChangeDF,cbind(0,rep("DMSO",length(foldChange[[1]]))))
lim=max(abs(foldChange[[1]]),abs(foldChange[[2]]))

colnames(foldChangeDF)=c("lfc","drug")
foldChangeDF=data.frame(foldChangeDF,check.names=FALSE,fix.empty.names=FALSE)
foldChangeDF$lfc=as.numeric(foldChangeDF$lfc)

pp=ggplot(foldChangeDF,aes(x=drug,y=lfc,fill="red")) +
geom_violin(alpha = 0.5) +
theme(legend.position = "none") + ylim(-3,3) + ggtitle("Groseq LogFoldChange AID Dependent")
plot(pp)   
print("Strongest")

write.table(filtering,(paste(results,"/gro_seq_geneWide_Strongest.csv",sep="")),sep=",",col.names=FALSE,row.names=FALSE,quote=FALSE)
print("Most DE")
write.table(filteringLFC,(paste(results,"/gro_seq_geneWide_mostDE.csv",sep="")),sep=",",col.names=FALSE,row.names=FALSE,quote=FALSE)


print("Most DE threshold")
write.table(thresholdTheBest,(paste(results,"/gro_seq_geneWide_mostDETreshold.csv",sep="")),sep=",",col.names=FALSE,row.names=FALSE,quote=FALSE)
# Out:
# [1] "Gene wide "
# [1] "Strongest"
# [1] "Most DE"
# [1] "Most DE threshold"
# plot without title

# %%
filtering
# Out:
#  [1] "GM16630" "CCL22"   "PLATR30" "GAS5"    "SNHG5"   "GM26689" "RPL36A"
#  [8] "RGP1"    "GM32687" "ZFP433"  "DUS4L"   "CEPT1"   "EFCAB2"  "DHX58"

# %%
filteringBS
# Out:
#   [1] "RN45S"          "HEXB"           "LARS2"          "CAMK1D"
#   [5] "IL31RA"         "CMSS1"          "FILIP1L"        "JARID2"
#   [9] "CD74"           "SSPN"           "ZC3H7A"         "CDK8"
#  [13] "ARHGAP21"       "KCNIP1"         "NEAT1"          "PEAK1"
#  [17] "RFTN1"          "NFATC1"         "PVT1"           "MALAT1"
#  [21] "D130009I18RIK"  "GPHN"           "MCL1"           "H2-K1"
#  [25] "TEX14"          "GTF2E1"         "SETDB1"         "C230035I16RIK"
#  [29] "CIITA"          "HERPUD1"        "EFL1"           "TCOF1"
#  [33] "CD44"           "GRAP"           "IQCN"           "CD69"
#  [37] "LOC547349"      "AI506816"       "D230017M19RIK"  "FOXP1"
#  [41] "HIVEP3"         "IL21R"          "ITPR1"          "B3GNT2"
#  [45] "HEG1"           "CCR7"           "MALT1"          "PRKCA"
#  [49] "FNDC3A"         "PRKCB"          "CHD2"           "HIVEP1"
#  [53] "TBC1D4"         "NDUFA13"        "2610005L07RIK"  "UBC"
#  [57] "MAN1A"          "CTSS"           "PHYKPL"         "GM16630"
#  [61] "DEXI"           "MIR6236"        "ZBTB20"         "MLLT11"
#  [65] "H2-Q6"          "SWAP70"         "DOCK2"          "HNRNPC"
#  [69] "NFKB1"          "SLC7A5"         "NCL"            "CD80"
#  [73] "GM16740"        "JADE2"          "GM15441"        "RN4.5S"
#  [77] "TRA2B"          "MEF2A"          "B4GALT1"        "CDKL4"
#  [81] "ARHGAP24"       "GADD45G"        "HSP90AB1"       "MIR155HG"
#  [85] "DOCK10"         "PSD"            "PPP1R15A"       "H2-Q8"
#  [89] "TRIM7"          "H2-D1"          "REL"            "TARDBP"
#  [93] "ZFP36L1"        "PLEK"           "TNFAIP3"        "BCL2L1"
#  [97] "PATL2"          "ARNT"           "DENND4A"        "AUH"
# [101] "RPL36A"         "GAS5"           "PLATR30"        "GM26689"
# [105] "CTH"            "A530040E14RIK"  "ANKRD11"        "SNHG5"
# [109] "HNRNPU"         "RBM39"          "SP140"          "PHGDH"
# [113] "MYC"            "MARS1"          "SH3BP5"         "EEF1AKMT4-ECE2"
# [117] "BAZ2B"          "RPL3"           "C130026I21RIK"  "TSPOAP1"
# [121] "WDFY4"          "SND1"           "4930557F10RIK"  "FAM126A"
# [125] "SP110"

# %%
filteringLFC
# Out:
#   [1] "BC037156"      "RAB9B"         "TSLP"          "1600012P17RIK"
#   [5] "LPPOS"         "HRNR"          "GM32172"       "IDO1"
#   [9] "GM17733"       "5930438M14RIK" "1700007F19RIK" "DHRS7C"
#  [13] "COL6A1"        "CYSLTR1"       "SELENOP"       "MS4A3"
#  [17] "IFIT1"         "PCDHB18"       "MINAR1"        "SPESP1"
#  [21] "RNF32"         "SPON2"         "HID1"          "ERMN"
#  [25] "9030619P08RIK" "BC055402"      "KLK12"         "6720483E21RIK"
#  [29] "RXFP3"         "CPB1"          "AI463170"      "MIR146B"
#  [33] "MCPT-PS1"      "FPR2"          "ARMCX2"        "GM31520"
#  [37] "GDF10"         "ELOVL4"        "NAT3"          "TDPOZ7"
#  [41] "TDPOZ5"        "OLFR169"       "ZFP760"        "APOL11A"
#  [45] "4930428E07RIK" "PCDHB20"       "1700027F09RIK" "SPATA46"
#  [49] "B930025P03RIK" "DMP1"          "MLPH"          "ZFP474"
#  [53] "PAQR9"         "HS3ST6"        "CAR2"          "HESX1"
#  [57] "NEUROD4"       "SVS2"          "NKX2-9"        "TMEM125"
#  [61] "FZD6"          "KLHL40"        "ADH6-PS1"      "CYSRT1"
#  [65] "KRT26"         "LUM"           "SNORD8"        "AGR2"
#  [69] "RNF144A"       "KLK11"         "FZD4"          "GUCY1B1"
#  [73] "BDNF"          "4930441J16RIK" "CD3G"          "C130021I20RIK"
#  [77] "SCGB1C1"       "1700060C16RIK" "IIGP1"         "4930554I06RIK"
#  [81] "OLFR1358"      "MIR8103"       "RAMP2"         "KLRK1"
#  [85] "GM16793"       "CFAP97D1"      "TMED11"        "MIR674"
#  [89] "GM5441"        "GOT1L1"        "MIRLET7B"      "MIR133C"
#  [93] "MIR6966"       "RETN"          "GM9508"        "TMEM132E"
#  [97] "D630039A03RIK" "PFPL"          "OAZ3"          "NAT8F3"
# [101] "MIR148B"       "PCDHB16"       "GM1600"        "IFIT3"
# [105] "MIR7073"       "KRT20"         "TAAR3"         "CSN1S2B"
# [109] "SIX3OS1"       "CYP26B1"       "INSM1"         "GPX5"
# [113] "1700042O10RIK" "4930467K11RIK" "LYRM7OS"       "FGF15"
# [117] "3110099E03RIK" "GJA4"          "TREML1"        "5330439B14RIK"
# [121] "MIR466I"       "CLCA2"         "MIR6362"       "ZFP941"
# [125] "TENT5B"        "SLC30A10"      "OLFR60"        "SYCP1-PS1"
# [129] "GM12530"       "IL3"           "CREG2"         "MIR5123"
# [133] "4930556L07RIK" "GM19277"       "BPIFB5"        "AI427809"
# [137] "DCPP3"         "HAO2"          "AKR1CL"        "CYP2D11"
# [141] "MIR378B"       "SERPINB9D"     "1700003M07RIK" "ECEL1"
# [145] "FABP4"         "SLN"           "MIR8098"       "S100A6"
# [149] "CLDN2"         "PON1"          "CCR3"

# %%
print("RAW")
Database=read.table(paste(previousResults,"Database.csv",sep="/"),header=TRUE,sep=",")
groseq_newrpm=as.matrix(read.table(paste(results,"/groSeq_AID_Heatmap_count.csv",sep=""),header=TRUE,row.names=1,sep=","))
filter=unique(union(rownames(read.table("/sharedFolder/Results/Ligase4/rpmPlot/sortNames/_2_DMSO_TAZE.csv",header=TRUE,row.names=1,sep=",")),rownames(read.table("/sharedFolder/Results/Ligase4/rpmPlot/sortNames/_5_DMSOVale.csv",header=TRUE,row.names=1,sep=","))))
filter=unlist(sapply(filter,FUN=function(x){toString(x)}))
groseq_newrpm=groseq_newrpm[filter,]
ttmp=groseq_newrpm[which(groseq_newrpm[,1]>=summary(groseq_newrpm[,1])[5]),]
thresholdTheBest=unique(union(names(sort(ttmp[,2]/ttmp[,1],decreasing=TRUE))[seq(1,20)],names(sort(ttmp[,3]/ttmp[,1],decreasing=TRUE))[seq(1,20)]))

foldChange=list()
geneWide=groseq_newrpm+0.000001
filteringTazeBS=names(sort(geneWide[,2],decreasing=TRUE))[seq(1,75)]
filteringValeBS=names(sort(geneWide[,3],decreasing=TRUE))[seq(1,75)]
filteringBS=union(filteringTazeBS,filteringValeBS)


#geneWide=geneWide[filtering,]
foldChange[[1]]=log2(geneWide[,2]/geneWide[,1])
foldChange[[2]]=log2(geneWide[,3]/geneWide[,1])


filteringTazeLFC=names(sort(foldChange[[1]],decreasing=TRUE))[seq(1,75)]
filteringValeLFC=names(sort(foldChange[[2]],decreasing=TRUE))[seq(1,75)]
filteringLFC=union(filteringTazeLFC,filteringValeLFC)

filtering=intersect(filteringBS,filteringLFC)

names(foldChange)=c("Taze","Vale")

foldChangeDF=cbind(foldChange[[1]],rep("Taze",length(foldChange[[1]])))
foldChangeDF=rbind(foldChangeDF,cbind(foldChange[[2]],rep("Vale",length(foldChange[[2]]))))
foldChangeDF=rbind(foldChangeDF,cbind(0,rep("DMSO",length(foldChange[[1]]))))
lim=max(abs(foldChange[[1]]),abs(foldChange[[2]]))

colnames(foldChangeDF)=c("lfc","drug")
foldChangeDF=data.frame(foldChangeDF,check.names=FALSE,fix.empty.names=FALSE)
foldChangeDF$lfc=as.numeric(foldChangeDF$lfc)

pp=ggplot(foldChangeDF,aes(x=drug,y=lfc,fill="red")) +
geom_violin(alpha = 0.5) +
geom_point(position = position_jitter(seed = 1, width = 0.2),size=0.1) +
theme(legend.position = "none") + ylim(-3,3) + ggtitle("Groseq LogFoldChange AID Dependent")
plot(pp)   
print("Strongest")
tempforever=c()
for(i in filtering){
temp=unique(Database[which(Database[,7]==i),c(1,2,3)])
tempforever=append(tempforever,(paste(temp[,1],":",temp[,2],"-",temp[,3],sep="")))
}
write.table(tempforever,(paste(results,"/gro_seq_raw_strongest.csv",sep="")),sep=",",col.names=FALSE,row.names=FALSE,quote=FALSE)
print("Most DE")
tempforever=c()

for(i in filteringLFC[seq(1,10)]){
temp=unique(Database[which(Database[,7]==i),c(1,2,3)])
tempforever=append(tempforever,(paste(temp[,1],":",temp[,2],"-",temp[,3],sep="")))

}
write.table(tempforever,(paste(results,"/gro_seq_raw_mostDE.csv",sep="")),sep=",",col.names=FALSE,row.names=FALSE,quote=FALSE)
tempforever=c()

print("Most DE with Threshold")
for(i in thresholdTheBest){
temp=unique(Database[which(Database[,7]==i),c(1,2,3)])
tempforever=append(tempforever,(paste(temp[,1],":",temp[,2],"-",temp[,3],sep="")))
}
write.table(tempforever,(paste(results,"/gro_seq_raw_mostDETreshold.csv",sep="")),sep=",",col.names=FALSE,row.names=FALSE,quote=FALSE)
# Out:
# [1] "RAW"
# [1] "Strongest"
# [1] "Most DE"
# [1] "Most DE with Threshold"
# plot without title

# %%
print("RAW")
Database=read.table(paste(previousResults,"Database.csv",sep="/"),header=TRUE,sep=",")
groseq_newrpm=as.matrix(read.table(paste(results,"/groSeq_AID_Heatmap_count.csv",sep=""),header=TRUE,row.names=1,sep=","))
filter=unique(union(rownames(read.table("/sharedFolder/Results/Ligase4/rpmPlot/filtered/sortNames/_2_DMSO_TAZE.csv",header=TRUE,row.names=1,sep=",")),rownames(read.table("/sharedFolder/Results/Ligase4/rpmPlot/filtered/sortNames/_5_DMSOVale.csv",header=TRUE,row.names=1,sep=","))))
filter=unlist(sapply(filter,FUN=function(x){toString(x)}))
groseq_newrpm=groseq_newrpm[filter,]
ttmp=groseq_newrpm[which(groseq_newrpm[,1]>=summary(groseq_newrpm[,1])[5]),]
thresholdTheBest=unique(union(names(sort(ttmp[,2]/ttmp[,1],decreasing=TRUE))[seq(1,20)],names(sort(ttmp[,3]/ttmp[,1],decreasing=TRUE))[seq(1,20)]))

foldChange=list()
geneWide=groseq_newrpm+0.000001
filteringTazeBS=names(sort(geneWide[,2],decreasing=TRUE))[seq(1,75)]
filteringValeBS=names(sort(geneWide[,3],decreasing=TRUE))[seq(1,75)]
filteringBS=union(filteringTazeBS,filteringValeBS)


#geneWide=geneWide[filtering,]
foldChange[[1]]=log2(geneWide[,2]/geneWide[,1])
foldChange[[2]]=log2(geneWide[,3]/geneWide[,1])


filteringTazeLFC=names(sort(foldChange[[1]],decreasing=TRUE))[seq(1,75)]
filteringValeLFC=names(sort(foldChange[[2]],decreasing=TRUE))[seq(1,75)]
filteringLFC=union(filteringTazeLFC,filteringValeLFC)

filtering=intersect(filteringBS,filteringLFC)

names(foldChange)=c("Taze","Vale")

foldChangeDF=cbind(foldChange[[1]],rep("Taze",length(foldChange[[1]])))
foldChangeDF=rbind(foldChangeDF,cbind(foldChange[[2]],rep("Vale",length(foldChange[[2]]))))
foldChangeDF=rbind(foldChangeDF,cbind(0,rep("DMSO",length(foldChange[[1]]))))
lim=max(abs(foldChange[[1]]),abs(foldChange[[2]]))

colnames(foldChangeDF)=c("lfc","drug")
foldChangeDF=data.frame(foldChangeDF,check.names=FALSE,fix.empty.names=FALSE)
foldChangeDF$lfc=as.numeric(foldChangeDF$lfc)

pp=ggplot(foldChangeDF,aes(x=drug,y=lfc,fill="red")) +
geom_violin(alpha = 0.5) +
geom_point(position = position_jitter(seed = 1, width = 0.2),size=0.1) +
theme(legend.position = "none") + ylim(-3,3) + ggtitle("Groseq LogFoldChange AID Dependent")
plot(pp)   
print("Strongest")
tempforever=c()
for(i in filtering){
temp=unique(Database[which(Database[,7]==i),c(1,2,3)])
tempforever=append(tempforever,(paste(temp[,1],":",temp[,2],"-",temp[,3],sep="")))
}
write.table(tempforever,(paste(results,"/gro_seq_raw_strongest.csv",sep="")),sep=",",col.names=FALSE,row.names=FALSE,quote=FALSE)
print("Most DE")
tempforever=c()

for(i in filteringLFC[seq(1,10)]){
temp=unique(Database[which(Database[,7]==i),c(1,2,3)])
tempforever=append(tempforever,(paste(temp[,1],":",temp[,2],"-",temp[,3],sep="")))

}
write.table(tempforever,(paste(results,"/gro_seq_raw_mostDE.csv",sep="")),sep=",",col.names=FALSE,row.names=FALSE,quote=FALSE)
tempforever=c()

print("Most DE with Threshold")
for(i in thresholdTheBest){
temp=unique(Database[which(Database[,7]==i),c(1,2,3)])
tempforever=append(tempforever,(paste(temp[,1],":",temp[,2],"-",temp[,3],sep="")))
}
write.table(tempforever,(paste(results,"/gro_seq_raw_mostDETreshold.csv",sep="")),sep=",",col.names=FALSE,row.names=FALSE,quote=FALSE)
# Out:
# [1] "RAW"
# [1] "Strongest"
# [1] "Most DE"
# [1] "Most DE with Threshold"
# plot without title
