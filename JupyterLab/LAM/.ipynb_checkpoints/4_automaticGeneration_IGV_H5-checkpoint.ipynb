# %%
# centering with 'scale()'
center_scale <- function(x) {
    scale(x, scale = FALSE)
}
library("pheatmap")
results="/sharedFolder/"
path="/sharedFolder/Data/1_HTGTS/13_Revision1/"
previousResults="/sharedFolder/Results/Hotspot/Revision1/FULL/"
results="/sharedFolder/Results/Hotspot/Revision1/FULL/"
library("ggVennDiagram");
library("ggplot2")
library("vioplot")
library(eulerr)
# Out:
# Loading required package: sm
#
# Package 'sm', version 2.2-5.7: type help(sm) for summary information
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric

# %%
for( jamesonFirst in c(5,6,7)){
f=jamesonFirst
Database=unique(read.table(paste(previousResults,"/",jamesonFirst,"Database.csv",sep="/"),header=TRUE,sep=","))#[,c(1,2,3,7)]


Database=Database[,c(1,2,3,6,7,8)]

DBTU=Database

rmarkdown=matrix(ncol=1)
rmarkdown=rbind(rmarkdown,"---")
rmarkdown=rbind(rmarkdown,'title: "Hotspots"')
rmarkdown=rbind(rmarkdown,"---")
#write batch file 
batch=matrix(ncol=1)




for(i in seq(1,nrow(DBTU))){
temp=(DBTU[i,3]-DBTU[i,2])*2
batch=rbind(batch,paste("goto ",DBTU[i,1],":",(DBTU[i,2]-temp),"-",(DBTU[i,3]+temp),sep=""))
batch=rbind(batch,paste("snapshot ",i,".png",sep=""))


johnTemp=" "
    
rmarkdown=rbind(rmarkdown,paste("## Hotspot ID ",DBTU[i,5],"- Belonging : ",DBTU[i,4]," Category:",DBTU[i,6],sep=""))
rmarkdown=rbind(rmarkdown,paste("![",johnTemp,"](./",i,".png",")",sep=""))
rmarkdown=rbind(rmarkdown," ")

}
batch=batch[-1,]
write.table(batch,paste(results,"/",jamesonFirst,"/",f,".batch",sep=""),col.names=FALSE,row.names=FALSE,sep="\t",quote=FALSE)
rmarkdown=rmarkdown[-1,]
write.table(rmarkdown,paste(results,"/",jamesonFirst,"/",f,".rmd",sep=""),row.names=FALSE,col.names=FALSE,quote=FALSE)
    }

# %%
Database
# Out:
#    Chromosome ChrStart  ChrEnd    hotspotID
# 16 chr2        46799107  46799362  89
# 17 chr2        88857470  88861556 133
# 18 chr3       120721827 120722553 135
# 19 chr4           27770     60429 136
# 20 chr6          390960    410647 137
# 21 chr8       145047853 145069370 144
# 22 chr9       130040335 130043784  96
# 23 chr11      135055498 135075423 147
# 24 chr12      133212408 133254800 149
# 25 chr13      114320599 114346317 151
# 26 chr14       39778755  39779319 152
# 27 chr19       13841092  13842117 129
# 28 chrY        11689523  11692805 108
# 29 chr2           13468     44932 132
# 30 chr2        88857470  88861556 133
# 31 chr3       120721827 120722553 135
# 32 chr4           27770     60429 136
# 33 chr6          390960    410647 137
# 34 chr8        84367726  84386907 116
# 35 chr8        91643826  91645465 117
# 36 chr8       107081903 107089459 118
# 37 chr8       115343081 115347118 119
# 38 chr8       139097941 139112059 120
# 39 chr11      135055498 135075423 147
# 40 chr12      133212408 133254800 149
# 41 chr14       39778755  39779319 152
# 42 chr18       80241236  80262378 156
# 43 chr19       13841092  13842117 129
# 44 chr1        28507123  28509733 131
# 45 chr2           13468     44932 132
# 46 chr2        88857470  88861556 133
# 47 chr3       120721827 120722553 135
# 48 chr4           27770     60429 136
# 49 chr6          390960    410647 137
# 50 chr6        82944468  82947007 139
# 51 chr8       111546096 111546545 141
# 52 chr8       121921212 121922295 142
# 53 chr8       128974388 128977013 143
# 54 chr8       145047853 145069370 144
# 55 chr11      135055498 135075423 147
# 56 chr12        8609246   8612105 148
# 57 chr12      133212408 133254800 149
# 58 chr13      114320599 114346317 151
# 59 chr14       39778755  39779319 152
# 60 chr18       80241236  80262378 156
# 61 chr19        2475529   2477090 157
