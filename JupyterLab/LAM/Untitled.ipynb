# %%
vettore=[50,11,100,94,22]

# %%
min=0
for i in range(len(vettore)):
    if vettore[i] > min:
# Out:
# 50
# 11
# 11
# 100
# 100
# 94
# 94
# 22
# 22
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 for i in range(len(vettore)):
#       2     print(vettore[i])
# ----> 3     print(vettore[i+1])
#
# IndexError: list index out of range
