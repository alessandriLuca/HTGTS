# %%
# centering with 'scale()'
center_scale <- function(x) {
    scale(x, scale = FALSE)
}
library("pheatmap")
results="/sharedFolder/Results/Ligase4/commonOverall"
dir.create(results)
previousResults="/sharedFolder/Results/Hotspot/"
library("ggVennDiagram");
library("ggplot2")
library("vioplot")
hotspotLists1=as.character(rownames(read.table(paste(results,"/../rpmPlot/filtered/sortNames/_2_DMSO_TAZE.csv",sep=""),header=TRUE,row.names=1,sep=",")))
hotspotLists2=as.character(rownames(read.table(paste(results,"/../rpmPlot/filtered/sortNames/_5_DMSOVale.csv",sep=""),header=TRUE,row.names=1,sep=",")))
Database=read.table(paste(previousResults,"Database_annotated.csv",sep="/"),header=TRUE,sep=",")
groSeq="/sharedFolder/Data/3_gro_seq/"
gro=read.table(paste(groSeq,"groseq_AID_Heatmap.csv",sep="/"),header=TRUE,row.names=1,sep=",")+0.000001
RNAseq="/sharedFolder/Data/2_RNA_seq/"
RNA=read.table(paste(RNAseq,"/RNA_AID_Heatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
ATAC="/sharedFolder/Data/6_Atacseq/"
Atac=read.table(paste(ATAC,"/ATAC_AID_Heatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
ACE="/sharedFolder/Data/5_CutTagAce/"
Ace=read.table(paste(ACE,"/CUT_AID_Heatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
HTGTS="/sharedFolder//Results/Ligase4/"
Htgts=read.table(paste(HTGTS,"/rpm_hgtgtsHeatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
# Out:
# Warning message in dir.create(results):
# “'/sharedFolder/Results/Ligase4/commonOverall' already exists”

# %%
hotspotLists1=as.character(rownames(read.table(paste(results,"/../rpmPlot/sortNames/_2_DMSO_TAZE.csv",sep=""),header=TRUE,row.names=1,sep=",")))
hotspotLists2=as.character(rownames(read.table(paste(results,"/../rpmPlot/sortNames/_5_DMSOVale.csv",sep=""),header=TRUE,row.names=1,sep=",")))
Database=read.table(paste(previousResults,"Database_annotated.csv",sep="/"),header=TRUE,sep=",")
groSeq="/sharedFolder/Data/3_gro_seq/"
gro=read.table(paste(groSeq,"groseq_AID_Heatmap.csv",sep="/"),header=TRUE,row.names=1,sep=",")+0.000001
RNAseq="/sharedFolder/Data/2_RNA_seq/"
RNA=read.table(paste(RNAseq,"/RNA_AID_Heatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
ATAC="/sharedFolder/Data/6_Atacseq/"
Atac=read.table(paste(ATAC,"/ATAC_AID_Heatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
ACE="/sharedFolder/Data/5_CutTagAce/"
Ace=read.table(paste(ACE,"/CUT_AID_Heatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
HTGTS="/sharedFolder//Results/Ligase4/"
Htgts=read.table(paste(HTGTS,"/rpm_hgtgtsHeatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
uuu=union(hotspotLists1,hotspotLists2)
LFCFinalT=matrix(nrow=length(hotspotLists1))
LFCFinalV=matrix(nrow=length(hotspotLists2))
LFCFinalT=cbind(LFCFinalT,log2(gro[hotspotLists1,2]/gro[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(gro[hotspotLists2,3]/gro[hotspotLists2,1]))
LFCFinalT=cbind(LFCFinalT,log2(Atac[hotspotLists1,2]/Atac[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(Atac[hotspotLists2,3]/Atac[hotspotLists2,1]))
LFCFinalT=cbind(LFCFinalT,log2(Ace[hotspotLists1,2]/Ace[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(Ace[hotspotLists2,3]/Ace[hotspotLists2,1]))
LFCFinalT=cbind(LFCFinalT,log2(Htgts[hotspotLists1,2]/Htgts[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(Htgts[hotspotLists2,3]/Htgts[hotspotLists2,1]))
LFCFinalT=cbind(LFCFinalT,log2(RNA[hotspotLists1,2]/RNA[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(RNA[hotspotLists2,3]/RNA[hotspotLists2,1]))
LFCFinalT=LFCFinalT[,-1]
LFCFinalV=LFCFinalV[,-1]
colnames(LFCFinalT)=c("groseq_Taze","atac_Taze","H3k27AC_Taze","Htgts_Taze","RNA_seq_Taze")
colnames(LFCFinalV)=c("groseq_Vale","atac_Vale","H3k27AC_Vale","Htgts_Vale","RNA_seq_Vale")


LFCFinalT[LFCFinalT>0]=1
LFCFinalT[LFCFinalT<0]=-1
LFCFinalT[LFCFinalT==0]=0
rownames(LFCFinalT)=hotspotLists1
LFCFinalV[LFCFinalV>0]=1
LFCFinalV[LFCFinalV<0]=-1
LFCFinalV[LFCFinalV==0]=0
rownames(LFCFinalV)=hotspotLists2
unfilteredT=LFCFinalT
unfilteredV=LFCFinalV
#COMPARE AGAINST HTGTS DATA unfiltered 
unf=matrix(ncol=3)
refT=unfilteredT[,grep("Htgts",colnames(unfilteredT))]
unfilteredT=unfilteredT[,-grep("Htgts",colnames(unfilteredT))]
for(i in seq(1,ncol(unfilteredT))){
vec=c(length(which(abs(refT+unfilteredT[,i])==2))/length(refT),"Taze",strsplit(colnames(unfilteredT)[i],"_Taze")[[1]][1])
unf=rbind(unf,vec)
}

refV=unfilteredV[,grep("Htgts",colnames(unfilteredV))]
unfilteredV=unfilteredV[,-grep("Htgts",colnames(unfilteredV))]
for(i in seq(1,ncol(unfilteredV))){
vec=c(length(which(abs(refV+unfilteredV[,i])==2))/length(refV),"Vale",strsplit(colnames(unfilteredV)[i],"_Vale")[[1]][1])
unf=rbind(unf,vec)
}
colnames(unf)=c("histF","groupF","cond")
unf=unf[-1,]
write.table(unf,paste(results,"/unfilteredConsistency.csv",sep=""),row.names=FALSE,sep=",")

# %%
hotspotLists1=as.character(rownames(read.table(paste(results,"/../rpmPlot/filtered/sortNames/_2_DMSO_TAZE.csv",sep=""),header=TRUE,row.names=1,sep=",")))
hotspotLists2=as.character(rownames(read.table(paste(results,"/../rpmPlot/filtered/sortNames/_5_DMSOVale.csv",sep=""),header=TRUE,row.names=1,sep=",")))
Database=read.table(paste(previousResults,"Database_annotated.csv",sep="/"),header=TRUE,sep=",")
groSeq="/sharedFolder/Data/3_gro_seq/"
gro=read.table(paste(groSeq,"groseq_AID_Heatmap.csv",sep="/"),header=TRUE,row.names=1,sep=",")+0.000001
RNAseq="/sharedFolder/Data/2_RNA_seq/"
RNA=read.table(paste(RNAseq,"/RNA_AID_Heatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
ATAC="/sharedFolder/Data/6_Atacseq/"
Atac=read.table(paste(ATAC,"/ATAC_AID_Heatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
ACE="/sharedFolder/Data/5_CutTagAce/"
Ace=read.table(paste(ACE,"/CUT_AID_Heatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
HTGTS="/sharedFolder//Results/Ligase4/"
Htgts=read.table(paste(HTGTS,"/rpm_hgtgtsHeatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
uuu=union(hotspotLists1,hotspotLists2)
LFCFinalT=matrix(nrow=length(hotspotLists1))
LFCFinalV=matrix(nrow=length(hotspotLists2))
LFCFinalT=cbind(LFCFinalT,log2(gro[hotspotLists1,2]/gro[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(gro[hotspotLists2,3]/gro[hotspotLists2,1]))
LFCFinalT=cbind(LFCFinalT,log2(Atac[hotspotLists1,2]/Atac[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(Atac[hotspotLists2,3]/Atac[hotspotLists2,1]))
LFCFinalT=cbind(LFCFinalT,log2(Ace[hotspotLists1,2]/Ace[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(Ace[hotspotLists2,3]/Ace[hotspotLists2,1]))
LFCFinalT=cbind(LFCFinalT,log2(Htgts[hotspotLists1,2]/Htgts[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(Htgts[hotspotLists2,3]/Htgts[hotspotLists2,1]))
LFCFinalT=cbind(LFCFinalT,log2(RNA[hotspotLists1,2]/RNA[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(RNA[hotspotLists2,3]/RNA[hotspotLists2,1]))
LFCFinalT=LFCFinalT[,-1]
LFCFinalV=LFCFinalV[,-1]
colnames(LFCFinalT)=c("groseq_Taze","atac_Taze","H3k27AC_Taze","Htgts_Taze","RNA_seq_Taze")
colnames(LFCFinalV)=c("groseq_Vale","atac_Vale","H3k27AC_Vale","Htgts_Vale","RNA_seq_Vale")


LFCFinalT[LFCFinalT>0]=1
LFCFinalT[LFCFinalT<0]=-1
LFCFinalT[LFCFinalT==0]=0
rownames(LFCFinalT)=hotspotLists1
LFCFinalV[LFCFinalV>0]=1
LFCFinalV[LFCFinalV<0]=-1
LFCFinalV[LFCFinalV==0]=0
rownames(LFCFinalV)=hotspotLists2
unfilteredT=LFCFinalT
unfilteredV=LFCFinalV
#COMPARE AGAINST HTGTS DATA unfiltered 
unf=matrix(ncol=3)
refT=unfilteredT[,grep("Htgts",colnames(unfilteredT))]
unfilteredT=unfilteredT[,-grep("Htgts",colnames(unfilteredT))]
for(i in seq(1,ncol(unfilteredT))){
vec=c(length(which(abs(refT+unfilteredT[,i])==2))/length(refT),"Taze",strsplit(colnames(unfilteredT)[i],"_Taze")[[1]][1])
unf=rbind(unf,vec)
}

refV=unfilteredV[,grep("Htgts",colnames(unfilteredV))]
unfilteredV=unfilteredV[,-grep("Htgts",colnames(unfilteredV))]
for(i in seq(1,ncol(unfilteredV))){
vec=c(length(which(abs(refV+unfilteredV[,i])==2))/length(refV),"Vale",strsplit(colnames(unfilteredV)[i],"_Vale")[[1]][1])
unf=rbind(unf,vec)
}
colnames(unf)=c("histF","groupF","cond")
unf=unf[-1,]
write.table(unf,paste(results,"/filteredConsistency.csv",sep=""),row.names=FALSE,sep=",")

# %%
hotspotLists1=as.character(rownames(read.table(paste(results,"/../rpmPlot/sortNames/_2_DMSO_TAZE.csv",sep=""),header=TRUE,row.names=1,sep=",")))
hotspotLists2=as.character(rownames(read.table(paste(results,"/../rpmPlot/sortNames/_5_DMSOVale.csv",sep=""),header=TRUE,row.names=1,sep=",")))
Database=read.table(paste(previousResults,"Database_annotated.csv",sep="/"),header=TRUE,sep=",")
groSeq="/sharedFolder/Data/3_gro_seq/"
gro=read.table(paste(groSeq,"groseq_AID_Heatmap.csv",sep="/"),header=TRUE,row.names=1,sep=",")+0.000001
RNAseq="/sharedFolder/Data/2_RNA_seq/"
RNA=read.table(paste(RNAseq,"/RNA_AID_Heatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
ATAC="/sharedFolder/Data/6_Atacseq/"
Atac=read.table(paste(ATAC,"/ATAC_AID_Heatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
ACE="/sharedFolder/Data/5_CutTagAce/"
Ace=read.table(paste(ACE,"/CUT_AID_Heatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
HTGTS="/sharedFolder//Results/Ligase4/"
Htgts=read.table(paste(HTGTS,"/rpm_hgtgtsHeatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
uuu=union(hotspotLists1,hotspotLists2)
LFCFinalT=matrix(nrow=length(hotspotLists1))
LFCFinalV=matrix(nrow=length(hotspotLists2))
#LFC=list()
#LFC[[1]]=log2(gro[hotspotLists1,2]/gro[hotspotLists1,1])
#LFC[[2]]=log2(gro[hotspotLists2,3]/gro[hotspotLists2,1])
#max=max(abs(c(log2(gro[hotspotLists1,2]/gro[hotspotLists1,1]),log2(gro[hotspotLists2,3]/gro[hotspotLists2,1]))))
#names(LFC)=c("Taze","Vale")
LFCFinalT=cbind(LFCFinalT,log2(gro[hotspotLists1,2]/gro[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(gro[hotspotLists2,3]/gro[hotspotLists2,1]))
#LFC=list()
#LFC[[1]]=log2(Atac[hotspotLists1,2]/Atac[hotspotLists1,1])
#LFC[[2]]=log2(Atac[hotspotLists2,3]/Atac[hotspotLists2,1])
#max=max(abs(c(log2(Atac[hotspotLists1,2]/Atac[hotspotLists1,1]),log2(Atac[hotspotLists2,3]/Atac[hotspotLists2,1]))))
#names(LFC)=c("Taze","Vale")
LFCFinalT=cbind(LFCFinalT,log2(Atac[hotspotLists1,2]/Atac[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(Atac[hotspotLists2,3]/Atac[hotspotLists2,1]))
#LFC=list()
#LFC[[1]]=log2(Ace[hotspotLists1,2]/Ace[hotspotLists1,1])
#LFC[[2]]=log2(Ace[hotspotLists2,3]/Ace[hotspotLists2,1])
#max=max(abs(c(log2(Ace[hotspotLists1,2]/Ace[hotspotLists1,1]),log2(Ace[hotspotLists2,3]/Ace[hotspotLists2,1]))))
#names(LFC)=c("Taze","Vale")
LFCFinalT=cbind(LFCFinalT,log2(Ace[hotspotLists1,2]/Ace[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(Ace[hotspotLists2,3]/Ace[hotspotLists2,1]))
#LFC=list()
#LFC[[1]]=log2(Htgts[hotspotLists1,2]/Htgts[hotspotLists1,1])
#LFC[[2]]=log2(Htgts[hotspotLists2,3]/Htgts[hotspotLists2,1])
#max=max(abs(c(log2(Htgts[hotspotLists1,2]/Htgts[hotspotLists1,1]),log2(Htgts[hotspotLists2,3]/Htgts[hotspotLists2,1]))))
#names(LFC)=c("Taze","Vale")
LFCFinalT=cbind(LFCFinalT,log2(Htgts[hotspotLists1,2]/Htgts[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(Htgts[hotspotLists2,3]/Htgts[hotspotLists2,1]))
#LFC=list()
#LFC[[1]]=log2(RNA[hotspotLists1,2]/RNA[hotspotLists1,1])
#LFC[[2]]=log2(RNA[hotspotLists2,3]/RNA[hotspotLists2,1])
#max=max(abs(c(log2(RNA[hotspotLists1,2]/RNA[hotspotLists1,1]),log2(RNA[hotspotLists2,3]/RNA[hotspotLists2,1]))))
#names(LFC)=c("Taze","Vale")
LFCFinalT=cbind(LFCFinalT,log2(RNA[hotspotLists1,2]/RNA[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(RNA[hotspotLists2,3]/RNA[hotspotLists2,1]))
LFCFinalT=LFCFinalT[,-1]
LFCFinalV=LFCFinalV[,-1]
colnames(LFCFinalT)=c("groseq_Taze","atac_Taze","H3k27AC_Taze","Htgts_Taze","RNA_seq_Taze")
colnames(LFCFinalV)=c("groseq_Vale","atac_Vale","H3k27AC_Vale","Htgts_Vale","RNA_seq_Vale")


LFCFinalT[LFCFinalT>0]=1
LFCFinalT[LFCFinalT<0]=-1
LFCFinalT[LFCFinalT==0]=0
rownames(LFCFinalT)=hotspotLists1
LFCFinalV[LFCFinalV>0]=1
LFCFinalV[LFCFinalV<0]=-1
LFCFinalV[LFCFinalV==0]=0
rownames(LFCFinalV)=hotspotLists2
unfilteredT=LFCFinalT
unfilteredV=LFCFinalV
valueT=abs(rowSums(LFCFinalT)/ncol(LFCFinalT))
valueV=abs(rowSums(LFCFinalV)/ncol(LFCFinalV))
foldChangeDF=list()
foldChangeDF=cbind(valueT,rep("Taze",length(valueT)))
foldChangeDF=rbind(foldChangeDF,cbind(valueV,rep("Vale",length(valueV))))

colnames(foldChangeDF)=c("lfc","drug")
foldChangeDF=data.frame(foldChangeDF)
foldChangeDF$lfc=as.numeric(foldChangeDF$lfc)

pp=ggplot(foldChangeDF,aes(x=drug,y=lfc,fill=drug)) +
geom_violin(alpha = 0.5,width=1) +
geom_point(position = position_jitter(seed = 1, width = 0.2)) +
theme(legend.position = "none") + ggtitle("Unfiltered Consistency between HTGTS,RNAseq,Groseq,H3k27AC,Atac")
plot(pp) 
LFCFinalT=LFCFinalT[,-2]
LFCFinalV=LFCFinalV[,-2]
valueT=abs(rowSums(LFCFinalT)/ncol(LFCFinalT))
valueV=abs(rowSums(LFCFinalV)/ncol(LFCFinalV))
foldChangeDF=list()
foldChangeDF=cbind(valueT,rep("Taze",length(valueT)))
foldChangeDF=rbind(foldChangeDF,cbind(valueV,rep("Vale",length(valueV))))

colnames(foldChangeDF)=c("lfc","drug")
foldChangeDF=data.frame(foldChangeDF)
foldChangeDF$lfc=as.numeric(foldChangeDF$lfc)

pp=ggplot(foldChangeDF,aes(x=drug,y=lfc,fill=drug)) +
geom_violin(alpha = 0.5,width=1) +
geom_point(position = position_jitter(seed = 1, width = 0.2)) +
theme(legend.position = "none") + ggtitle("Unfiltered Consistency between HTGTS,RNAseq,Groseq,H3k27AC")
plot(pp)
# Out:
# plot without title
# plot without title

# %%
hotspotLists1=as.character(rownames(read.table(paste(results,"/../rpmPlot/filtered/sortNames/_2_DMSO_TAZE.csv",sep=""),header=TRUE,row.names=1,sep=",")))
hotspotLists2=as.character(rownames(read.table(paste(results,"/../rpmPlot/filtered/sortNames/_5_DMSOVale.csv",sep=""),header=TRUE,row.names=1,sep=",")))
Database=read.table(paste(previousResults,"Database_annotated.csv",sep="/"),header=TRUE,sep=",")
groSeq="/sharedFolder/Data/3_gro_seq/"
gro=read.table(paste(groSeq,"groseq_AID_Heatmap.csv",sep="/"),header=TRUE,row.names=1,sep=",")+0.000001
RNAseq="/sharedFolder/Data/2_RNA_seq/"
RNA=read.table(paste(RNAseq,"/RNA_AID_Heatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
ATAC="/sharedFolder/Data/6_Atacseq/"
Atac=read.table(paste(ATAC,"/ATAC_AID_Heatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
ACE="/sharedFolder/Data/5_CutTagAce/"
Ace=read.table(paste(ACE,"/CUT_AID_Heatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
HTGTS="/sharedFolder//Results/Ligase4/"
Htgts=read.table(paste(HTGTS,"/rpm_hgtgtsHeatmap.csv",sep=""),header=TRUE,row.names=1,sep=",")+0.000001
uuu=union(hotspotLists1,hotspotLists2)
LFCFinalT=matrix(nrow=length(hotspotLists1))
LFCFinalV=matrix(nrow=length(hotspotLists2))
LFC=list()
LFC[[1]]=log2(gro[hotspotLists1,2]/gro[hotspotLists1,1])
LFC[[2]]=log2(gro[hotspotLists2,3]/gro[hotspotLists2,1])
max=max(abs(c(log2(gro[hotspotLists1,2]/gro[hotspotLists1,1]),log2(gro[hotspotLists2,3]/gro[hotspotLists2,1]))))
names(LFC)=c("Taze","Vale")
LFCFinalT=cbind(LFCFinalT,log2(gro[hotspotLists1,2]/gro[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(gro[hotspotLists2,3]/gro[hotspotLists2,1]))
LFC=list()
LFC[[1]]=log2(Atac[hotspotLists1,2]/Atac[hotspotLists1,1])
LFC[[2]]=log2(Atac[hotspotLists2,3]/Atac[hotspotLists2,1])
max=max(abs(c(log2(Atac[hotspotLists1,2]/Atac[hotspotLists1,1]),log2(Atac[hotspotLists2,3]/Atac[hotspotLists2,1]))))
names(LFC)=c("Taze","Vale")
LFCFinalT=cbind(LFCFinalT,log2(Atac[hotspotLists1,2]/Atac[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(Atac[hotspotLists2,3]/Atac[hotspotLists2,1]))
LFC=list()
LFC[[1]]=log2(Ace[hotspotLists1,2]/Ace[hotspotLists1,1])
LFC[[2]]=log2(Ace[hotspotLists2,3]/Ace[hotspotLists2,1])
max=max(abs(c(log2(Ace[hotspotLists1,2]/Ace[hotspotLists1,1]),log2(Ace[hotspotLists2,3]/Ace[hotspotLists2,1]))))
names(LFC)=c("Taze","Vale")
LFCFinalT=cbind(LFCFinalT,log2(Ace[hotspotLists1,2]/Ace[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(Ace[hotspotLists2,3]/Ace[hotspotLists2,1]))
LFC=list()
LFC[[1]]=log2(Htgts[hotspotLists1,2]/Htgts[hotspotLists1,1])
LFC[[2]]=log2(Htgts[hotspotLists2,3]/Htgts[hotspotLists2,1])
max=max(abs(c(log2(Htgts[hotspotLists1,2]/Htgts[hotspotLists1,1]),log2(Htgts[hotspotLists2,3]/Htgts[hotspotLists2,1]))))
names(LFC)=c("Taze","Vale")
LFCFinalT=cbind(LFCFinalT,log2(Htgts[hotspotLists1,2]/Htgts[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(Htgts[hotspotLists2,3]/Htgts[hotspotLists2,1]))
LFC=list()
LFC[[1]]=log2(RNA[hotspotLists1,2]/RNA[hotspotLists1,1])
LFC[[2]]=log2(RNA[hotspotLists2,3]/RNA[hotspotLists2,1])
max=max(abs(c(log2(RNA[hotspotLists1,2]/RNA[hotspotLists1,1]),log2(RNA[hotspotLists2,3]/RNA[hotspotLists2,1]))))
names(LFC)=c("Taze","Vale")
LFCFinalT=cbind(LFCFinalT,log2(RNA[hotspotLists1,2]/RNA[hotspotLists1,1]))
LFCFinalV=cbind(LFCFinalV,log2(RNA[hotspotLists2,3]/RNA[hotspotLists2,1]))
LFCFinalT=LFCFinalT[,-1]
LFCFinalV=LFCFinalV[,-1]
colnames(LFCFinalT)=c("groseq_Taze","atac_Taze","H3k27AC_Taze","Htgts_Taze","RNA_seq_Taze")
colnames(LFCFinalV)=c("groseq_Vale","atac_Vale","H3k27AC_Vale","Htgts_Vale","RNA_seq_Vale")
LFCFinalT[LFCFinalT>0]=1
LFCFinalT[LFCFinalT<0]=-1
LFCFinalT[LFCFinalT==0]=0
rownames(LFCFinalT)=hotspotLists1
LFCFinalV[LFCFinalV>0]=1
LFCFinalV[LFCFinalV<0]=-1
LFCFinalV[LFCFinalV==0]=0
rownames(LFCFinalV)=hotspotLists2
filteredT=LFCFinalT
filteredV=LFCFinalV

valueT=abs(rowSums(LFCFinalT)/ncol(LFCFinalT))
valueV=abs(rowSums(LFCFinalV)/ncol(LFCFinalV))
foldChangeDF=list()
foldChangeDF=cbind(valueT,rep("Taze",length(valueT)))
foldChangeDF=rbind(foldChangeDF,cbind(valueV,rep("Vale",length(valueV))))

colnames(foldChangeDF)=c("lfc","drug")
foldChangeDF=data.frame(foldChangeDF)
foldChangeDF$lfc=as.numeric(foldChangeDF$lfc)

pp=ggplot(foldChangeDF,aes(x=drug,y=lfc,fill=drug)) +
geom_violin(alpha = 0.5,width=1) +
geom_point(position = position_jitter(seed = 1, width = 0.2)) +
theme(legend.position = "none") + ggtitle("Filtered Consistency between HTGTS,RNAseq,Groseq,H3k27AC,Atacseq")
plot(pp) 
hist(valueT,label=TRUE,main="Filtered Taze Consistency between HTGTS,RNAseq,Groseq,H3k27AC,Atacseq")
hist(valueV,label=TRUE,main="Filtered Vale Consistency between HTGTS,RNAseq,Groseq,H3k27AC,Atacseq")

LFCFinalT=LFCFinalT[,-2]
LFCFinalV=LFCFinalV[,-2]
valueT=abs(rowSums(LFCFinalT)/ncol(LFCFinalT))
valueV=abs(rowSums(LFCFinalV)/ncol(LFCFinalV))
foldChangeDF=list()
foldChangeDF=cbind(valueT,rep("Taze",length(valueT)))
foldChangeDF=rbind(foldChangeDF,cbind(valueV,rep("Vale",length(valueV))))

colnames(foldChangeDF)=c("lfc","drug")
foldChangeDF=data.frame(foldChangeDF)
foldChangeDF$lfc=as.numeric(foldChangeDF$lfc)

pp=ggplot(foldChangeDF,aes(x=drug,y=lfc,fill=drug)) +
geom_violin(alpha = 0.5,width=1) +
geom_point(position = position_jitter(seed = 1, width = 0.001)) +
theme(legend.position = "none") + ggtitle("Filtered Consistency between HTGTS,RNAseq,Groseq,H3k27AC")
plot(pp)
# Out:
# plot without title
# Plot with title “Filtered Taze Consistency between HTGTS,RNAseq,Groseq,H3k27AC,Atacseq”
# Plot with title “Filtered Vale Consistency between HTGTS,RNAseq,Groseq,H3k27AC,Atacseq”
# plot without title

# %%
conditions=c("groseq_Taze","atac_Taze","H3k27AC_Taze","Htgts_Taze","RNA_seq_Taze")
conditionsRaw=c("groseq","atac","H3k27AC","Htgts","RNA_seq")

histF=c()
histUnf=c()
groupF=c()
groupUnf=c()
count=1
cond=c()
for(i in conditions){
htgts=colnames(filteredT)[grep("Htgts",colnames(filteredT))]
histF=append(histF,length(which(abs(rowSums(filteredT[,c(i,htgts)])/2)==1))/nrow(filteredT)*100)
groupF=append(groupF,"Taze")
htgts=colnames(unfilteredT)[grep("Htgts",colnames(filteredT))]
histUnf=append(histUnf,length(which(abs(rowSums(unfilteredT[,c(i,htgts)])/2)==1))/nrow(filteredT)*100)
groupUnf=append(groupUnf,"Taze")
cond=append(cond,conditionsRaw[count])
    count=count+1
}

conditions=c("groseq_Vale","atac_Vale","H3k27AC_Vale","Htgts_Vale","RNA_seq_Vale")
count=1
for(i in conditions){
htgts=colnames(filteredV)[grep("Htgts",colnames(filteredV))]
histF=append(histF,length(which(abs(rowSums(filteredV[,c(i,htgts)])/2)==1))/nrow(filteredV)*100)
groupF=append(groupF,"Vale")

    
htgts=colnames(unfilteredV)[grep("Htgts",colnames(unfilteredV))]
histUnf=append(histUnf,length(which(abs(rowSums(unfilteredV[,c(i,htgts)])/2)==1))/nrow(unfilteredV)*100)
groupUnf=append(groupUnf,"Vale")
    cond=append(cond,conditionsRaw[count])

count=count+1
}
f=data.frame(cbind(histF,groupF,cond))
unf=data.frame(cbind(histUnf,groupUnf,cond))
ggplot(f, aes(fill=groupF, y=histF,x=cond)) + 
    geom_bar(position="dodge", stat="identity") + ggtitle("Filtered Consistency between HTGTS,RNAseq,Groseq,H3k27AC")

ggplot(unf, aes(fill=groupF, y=histF,x=cond)) + 
    geom_bar(position="dodge", stat="identity")  + ggtitle("UnFiltered Consistency between HTGTS,RNAseq,Groseq,H3k27AC")
write.table(f,paste(results,"/filteredConsistency.csv",sep=""),row.names=FALSE,sep=",")
# Out:
# plot without title
# plot without title

# %%
f
# Out:
#    histF            groupF cond
# 1  78.2608695652174 Taze   groseq
# 2  39.1304347826087 Taze   atac
# 3  60.8695652173913 Taze   H3k27AC
# 4  100              Taze   Htgts
# 5  91.304347826087  Taze   RNA_seq
# 6  60.8695652173913 Vale   groseq
# 7  30.4347826086957 Vale   atac
# 8  78.2608695652174 Vale   H3k27AC
# 9  104.347826086957 Vale   Htgts
# 10 95.6521739130435 Vale   RNA_seq

# %%
unf
# Out:
#    histUnf          groupUnf cond
# 1  430.434782608696 Taze     groseq
# 2  265.217391304348 Taze     atac
# 3  391.304347826087 Taze     H3k27AC
# 4  643.478260869565 Taze     Htgts
# 5  452.173913043478 Taze     RNA_seq
# 6  321.739130434783 Vale     groseq
# 7  260.869565217391 Vale     atac
# 8  395.652173913043 Vale     H3k27AC
# 9  639.130434782609 Vale     Htgts
# 10 421.739130434783 Vale     RNA_seq

# %%
unf
# Out:
#   histUnf          groupUnf cond
# 1 70.2702702702703 Taze     RNA_seq
# 2 66.8918918918919 Taze     groseq
# 3 60.8108108108108 Taze     H3k27AC
# 4 65.9863945578231 Vale     RNA_seq
# 5 50.3401360544218 Vale     groseq
# 6 61.9047619047619 Vale     H3k27AC
